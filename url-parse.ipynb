# %%
from bs4 import BeautifulSoup
import requests
import requests.exceptions
from urllib.parse import urlsplit
from collections import deque
import re

# %%
new_urls = deque(['https://franceisai.com/startups'])

# %%
processed_urls = set()

# %%
emails = set()

# %%
while len(new_urls):
    url= new_urls.popleft()
    processed_urls.add(url)

# %%
#extract base url and path to resolve relative links
parts = urlsplit(url)
base_url = "{0.scheme}://{0.netloc}".format(parts)
path = url[:url.rfind('/')+1] if '/' in parts.path else url

# %%
# get url's content
print("processing %s" % url)
try:
    response = requests.get(url)
except(requests.exceptions.MissingSchema, requests.exceptions.ConnectionError):
    #ignore pages with errors
    Continue
# Out:
# processing https://franceisai.com/startups

# %%
#extract all email addresses and add them into the resulting set
new_emails = set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", response.text, re.I))
emails.update(new_emails)

# %%
# create a beautiful Soup for the html document
soup = BeautifulSoup(response.text, "lxml")

# %%
#Find and process all the anchors in the documents
for anchor in soup.find_all("a"):
    #extract link url from the anchor
    link = anchor.attrs["href"] if "href" in anchor.attrs else ''

# %%
#Add base url to relative links
if link.startswith('/'):
    link = base_url + link

# %%
#Add the new url to the queue if it's of HTTP protocol, not enqueued and not processed yet
if link.startswith('http') and not link in new_urls and not link in processed_urls:
    new_urls.append(link)

# %%
print(new_emails)
# Out:
# set()

# %%
print(response.text)
# Out:
# <!DOCTYPE html><html lang="fr-FR" prefix="og: http://ogp.me/ns#"><head> <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-M97KFNW');</script> <meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta name="mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-title" content="France is AI - Description"><meta name="theme-color" content="#F7F7F7"><title>French startups players in Artificial Intelligence- France is AI</title><meta name="description" content="Discover many French startups leveraging AI in a variety of applications that boosted the ecosystem in France. France is AI draws startups that are players in Artificial Intelligence, the ecosystem." /><link rel="canonical" href="https://franceisai.com/startups" /><link rel="next" href="https://franceisai.com/startups/page/2" /><meta property="og:locale" content="fr_FR" /><meta property="og:type" content="object" /><meta property="og:title" content="French startups players in Artificial Intelligence- France is AI" /><meta property="og:url" content="https://franceisai.com/startups" /><meta property="og:site_name" content="France is AI" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:description" content="Discover many French startups leveraging AI in a variety of applications that boosted the ecosystem in France. France is AI draws startups that are players in Artificial Intelligence, the ecosystem." /><meta name="twitter:title" content="French startups players in Artificial Intelligence- France is AI" /><link rel='dns-prefetch' href='//cdn.datatables.net' /><link rel='dns-prefetch' href='//cdnjs.cloudflare.com' /><link rel='dns-prefetch' href='//maps.googleapis.com' /><link rel='dns-prefetch' href='//fonts.googleapis.com' /><link rel='dns-prefetch' href='//s.w.org' /><link rel="alternate" type="application/rss+xml" title="France is AI &raquo; Flux" href="https://franceisai.com/feed" /><link rel="alternate" type="application/rss+xml" title="France is AI &raquo; Flux des commentaires" href="https://franceisai.com/comments/feed" /><link rel="alternate" type="application/rss+xml" title="France is AI &raquo; Flux pour Startup" href="https://franceisai.com/startups/feed/" /><style type="text/css">img.wp-smiley,img.emoji{display:inline!important;border:none!important;box-shadow:none!important;height:1em!important;width:1em!important;margin:0 .07em!important;vertical-align:-0.1em!important;background:none!important;padding:0!important}</style><link rel='stylesheet' id='_pit-datatables-css' href='//cdn.datatables.net/1.10.16/css/jquery.dataTables.min.css?ver=4.9.5' type='text/css' media='all' /><link rel='stylesheet' id='_pit-css-css' href='https://franceisai.com/wp-content/themes/france-is-ai/assets/css/style.css?ver=4.9.5' type='text/css' media='all' /><link rel='stylesheet' id='_pit-css-default-css' href='https://franceisai.com/wp-content/themes/france-is-ai/style.css?ver=4.9.5' type='text/css' media='all' /><link rel='stylesheet' id='_pit-slick_style-css' href='https://franceisai.com/wp-content/themes/france-is-ai/assets/css/lib/slick.css?ver=4.9.5' type='text/css' media='all' /><link rel='stylesheet' id='_pit-slick_style_theme-css' href='https://franceisai.com/wp-content/themes/france-is-ai/assets/css/lib/slick-theme.css?ver=4.9.5' type='text/css' media='all' /><link rel='stylesheet' id='_pit-font-source-sans-css' href='https://fonts.googleapis.com/css?family=Source+Sans+Pro%3A400%2C700&#038;ver=4.9.5' type='text/css' media='all' /><link rel='stylesheet' id='_pit-font-josefin-sans-css' href='https://fonts.googleapis.com/css?family=Josefin+Sans%3A400%2C500%2C700%2C900&#038;ver=4.9.5' type='text/css' media='all' /><link rel='stylesheet' id='af-form-style-css' href='https://franceisai.com/wp-content/plugins/advanced-forms/assets/css/form.css?ver=4.9.5' type='text/css' media='all' /> <script type='text/javascript' src='https://franceisai.com/wp-includes/ ...
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><header><nav class="menu menu-me menu-scroll"> <input type="checkbox" id="toggle" /><ul><li class="logo"><a href="https://franceisai.com"><img src="https://franceisai.com/wp-content/uploads/france-is-ai-logo-startup.png" alt="France is AI" title="France is AI" class="img-responsive" /></a></a></li><li class="burger"><label for="toggle"><span></span></label></li><li id="menu-item-2513" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2513"><a href="#">Conferences</a><ul class="sub-menu"><li id="menu-item-612" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-612"><a href="https://franceisai.com/conferences/conference-2017">Conference 2017</a></li><li id="menu-item-2572" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2572"><a href="http://ai-night.com">AI Night 2018</a></li></ul></li><li id="menu-item-2320" class="menu-item menu-item-type-post_type_archive menu-item-object-startup current-menu-item menu-item-2320"><a href="https://franceisai.com/startups">Startups</a></li><li id="menu-item-2321" class="menu-item menu-item-type-post_type_archive menu-item-object-research-center menu-item-2321"><a href="https://franceisai.com/research">Research</a></li><li id="menu-item-462" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-462"><a href="https://franceisai.com/education">Education</a></li><li id="menu-item-2322" class="menu-item menu-item-type-post_type_archive menu-item-object-community menu-item-2322"><a href="https://franceisai.com/community">Community</a></li><li id="menu-item-2323" class="menu-item menu-item-type-post_type_archive menu-item-object-event menu-item-2323"><a href="https://franceisai.com/calendar">Calendar</a></li><li id="menu-item-459" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-459"><a href="https://franceisai.com/about-us">About us</a></li><li id="menu-item-458" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-458"><a href="https://franceisai.com/partners">Partners</a></li><li class="lang menu-item"><ul><li id="menu-item-674" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-674"><a href="#">EN</a><ul class="sub-menu"><li id="menu-item-673" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-673"><a href="#">FR</a></li></ul></li></ul></li></ul></nav></header><section><div class="cta bg-cover bg-fixed pos-rlt has-bg" style="background-color: #062048;"> <img class="pos-abt h-full bg-left" src="https://franceisai.com/wp-content/uploads/bg-particules-2-reverse-1.png" alt="" /><img class="pos-abt h-full bg-right" src="https://franceisai.com/wp-content/uploads/bg-particules-2-1.png" alt="" /><div class="_pit-section  normal"><div class="section-menu-padding"></div><div class="section-introduction"><div class="container"><h1>Discover 285+ French startups leveraging AI in a variety of applications</h1> <a target="" href="https://franceisai.com/startups/add-startup" class="btn plain white primary">Add your start up<i class="fa fa-long-arrow-right m-l-6"></i></a></div></div></div></div></section><section class="contenu"><div class="section-menu-padding"></div><div class="_pit-section "><div class="container"><p><img class="aligncenter size-full wp-image-2676" src="https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59.png" alt="" width="1404" height="984" srcset="https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59.png 1404w, https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59-250x175.png 250w, https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59-768x538.png 768w, https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59-700x491.png 700w, https://franceisai.com/wp-content/uploads/c ...
# Our high-end strategic tools based on Deep Learning and Image recognition allow retailers to industrialize their benchmarking activities and align billions of products on their taxonomy. Our company was founded by former strategy consultants and data experts, and also offers customized, cutting-edge predictive solutions to retail leaders in France and abroad.</td><td class="text-primary">AI as a Service, Clothing and Apparel, Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics, Platforms | Vision, Platforms | Big Data, Retail, Enterprise | Business + Predictive Intelligence, Big Data / Machine Learning, E-Commerce, Machine Learning</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="databerries"> <a class="text-primary" href="http://www.databerries.com/"> Databerries </a></td><td>DataBerries offers performance mobile marketing campaigns powered by machine learning algorithms.</td><td class="text-primary">AdTech</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="17.86">17.86 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="dataiku"> <a class="text-primary" href="http://www.dataiku.com"> Dataiku </a></td><td>Dataiku develops Data Science Studio, the tool that lets data scientists and analysts do machine learning on any (dirty) data.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="45.7">45.7 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="datananas"> <a class="text-primary" href="https://www.datananas.com"> Datananas </a></td><td>Datananas builds B2B prospect lists from professional social networks to generate new Outbound leads without cold calling.</td><td class="text-primary">Enterprise | Sales and Marketing, Software</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="datapred"> <a class="text-primary" href="http://www.datapred.com"> Datapred </a></td><td>Datapred provides a cutting-edge algorithmic engine that helps businesses take advantage of the huge amounts of data they generate and that surround them.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="datapublica / c-radar"> <a class="text-primary" href="http://www.c-radar.com"> DataPublica / C-Radar </a></td><td>C-Radar is a B2B predictive marketing platform that helps identify new potential customers.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="dataswati"> <a class="text-primary" href="http://dataswati.com"> Dataswati </a></td><td>Dataswati develops PowerOp, an AI to improve industrial processes and boost factory output based on various datasources (sensors, images, written reports and procedures).</td><td class="text-primary">AI as a Service, Manufacturing / Logistics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="davi"> <a class="text-primary" href="http://www.davi.ai/"> DAVI </a></td><td>DAVI has developed a Digital Agent solution leveraging 3D animation engine and Natural Language Processing (NLP), to transform the digital relationship into a human relationship.</td><td class="text-primary">Agents | Platfor ...
# Designed around the latest technologies (NoSQL, Cassandra, Elasticsearch, Cloud, Hadoop, etc.), it allows to collect and aggregate all types of multi-fluid data from heterogeneous sources. These data are then made reliable and rendered via multi-level and multi-role dashboards. Energisme provides its customers with predictive modeling tools and an ecosystem of partners to anticipate and optimize their consumption.
# In 2015, the company was taken over by three entrepreneurs with complementary paths and has since grown rapidly. It has multiplied by five its workforce in less than two years. Engaged in the energy transition of the public sector, Energisme launched in early February Energisme Freemium, a free version of its Big Data platform, for local authorities and public institutions.</td><td class="text-primary">City / Infrastructures, Energy, Enterprise | Big Data and Analytics, Platforms | Big Data, Software, Sustainability, Machine Learning, Predictive Intelligence, IoT</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="6">6 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="eos innovation"> <a class="text-primary" href="http://www.eos-innovation.eu"> EOS Innovation </a></td><td>EOS Innovation conceives and designs, develops and markets e-vigilante, a mobile surveillance robot.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="event bots"> <a class="text-primary" href="http://www.event-bots.fr/"> Event Bots </a></td><td>Event Bots develops robots specialized for events, including Tiki - a welcome robot.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="exensa"> <a class="text-primary" href="http://www.exensa.com"> Exensa </a></td><td>eXenSa provides Machine Learning solutions including an analytics engine.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="0.3">0.3 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="exotec solutions"> <a class="text-primary" href="http://www.exotecsolutions.com/"> Exotec Solutions </a></td><td>Exotec proposes a disruptive order preparation system based on mobile robots, allowing to increase efficiency while keeping a total agility</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="4.3">4.3 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="facten"> <a class="text-primary" href="https://www.facten.com/"> Facten </a></td><td>Facten is a B2B Sales application focused on Science and Technology companies, scanning and analyzing every patent, every scientific article, every tender, every public grant.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="fieldbox.ai"> <a class="text-primary" href="https://www.fieldbox.ai/en/ai-for-industry/"> Fieldbox.ai </a></td><td>FieldBox.ai helps industries dramatically improve their operational efficiency thanks to artificial intelligence. The FieldBox.ai platform makes it possible to deploy AI-trained industrial bots in the heart of factories. These bots continuously and autonomously optimize processes and operate machines. By relocating decision making in factories, and automating it with AI, FieldBox.ai dramatically reduces the costs and time required to fulfill the promises of Industry 4.0.</td><td class="text-primary">Energy, Enterprise | Big Data and Analytics, Internet of Things, Oil</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="flylab"> <a class="text-primary" href="http://flylab.io"> Flylab </a></td><td>Flylab develops software and Hardware/Processing  ...
# These natural language text and voice interfaces facilitate information search, helping individuals at home or in the office to gain time and efficiency.</td><td class="text-primary">Bots | Platform and Tools, Bots | Professional, Connected home, Enterprise, Platforms | Natural Language, Machine Learning, Productivity and Well-being, or Personal agent</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="hease robotics"> <a class="text-primary" href="http://heaserobotics.com"> Hease Robotics </a></td><td>HEASE, the first robot tailored for retail and hospitality. HEASE informs, entertains, guides and welcomes your audience.</td><td class="text-primary">Retail, Robotics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="heek"> <a class="text-primary" href="http://www.heek.com"> Heek </a></td><td>Heek is a conversational website builder.</td><td class="text-primary">Bots | Professional, Professional Services</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="0.77">0.77 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="hellebore technologies"> <a class="text-primary" href="http://www.helleboretech.com/"> Hellebore Technologies </a></td><td>Hellebore Technologies develops Machine Learning and Data Mining solutions for OTC Markets.</td><td class="text-primary">AI as a Service, Enterprise | Big Data and Analytics, Platforms | Natural Language, Platforms | Big Data, Professional Services, Science and Engineering, Software, Financial Services, Lending and investments</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="hello jam"> <a class="text-primary" href="https://hellojam.fr"> Hello JAM </a></td><td>Jam uses Artificial Intelligence and Process Optimization to help you find things to do during your free time.</td><td class="text-primary">Agents | Personal</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="1.5">1.5 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="hellotrip"> <a class="text-primary" href="http://hellotrip.com"> Hellotrip </a></td><td>Hellotrip has developed an airfare prediction technology.</td><td class="text-primary">Hospitality</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="heuritech"> <a class="text-primary" href="http://www.heuritech.com"> Heuritech </a></td><td>Heuritech enables brands to find relevant trends related to products, to improve product design and launching, by monitors blogs, images and videos to detect products in their contexts.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="1.17">1.17 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="hins"> <a class="text-primary" href="http://www.claytheworld.com"> HINS </a></td><td>HINS develops CLAY, a software solution for automated and adaptive hand recognition from simple 2D lens on smartphones. It notably adresses industrials and VR big accounts.</td><td class="text-primary">AI as a Service</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="honestica"> <a class="text-primary" href="http://www.honestica.com"> Honestica </a></td><td>Honestica provides a global platform to facilitate collaboration between phy ...
# Our technology rests on a combination of specifically trained natural language processing algorithms and advanced deep learning techniques.</td><td class="text-primary">Administrative Services, Legal, Software</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="1.23">1.23 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="ideta"> <a class="text-primary" href="http://www.meet-ideta.com/"> Ideta </a></td><td>Ideta is a SaaS solution for Retailers and E-commerce to engage with visitors in a digital conversation and unlock prospects purchasing potential, enhancing online and in-store customer experience.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Retail</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="immersive robotics"> <a class="text-primary" href="http://immersive-robotics.com/"> Immersive Robotics </a></td><td>Immersive robotics produces robots, including Waldo, a humanoid robot designed for customer service, people assistance and research.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="implicity"> <a class="text-primary" href="http://www.implicity.fr"> Implicity </a></td><td>Implicty offers a smart monitoring solution for Pacemakers and Defibrillators with AI algorithms combining device data and patients health records to determine every alert’s criticality.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="incalia"> <a class="text-primary" href="http://incalia.fr"> Incalia </a></td><td>Incalia builds custom Machine & Deep Learning solutions for start ups​.</td><td class="text-primary">AI as a Service</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="innoradiant"> <a class="text-primary" href="https://innoradiant.com/"> Innoradiant </a></td><td>Innoradiant leverages NLP to help companies with product development and innovation.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Sales and Marketing, Platforms | Natural Language</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="intuitive-robots.com"> <a class="text-primary" href="http://Intuitive-robots.com"> Intuitive-robots.com </a></td><td>Intuitive Robots has developed a software to facilitate the usage of humanoid robots like Pepper include Ready-to-use solution & applications...</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="invenis"> <a class="text-primary" href="https://invenis.paris/"> Invenis </a></td><td>Invenis offers a self-service advanced Big Data / Analytics software, with no coding / analytics skills required.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="io-technology"> <a class="text-primary" href="http://www.io-technology.net/"> IO-Technology </a></td><td>IO-Technology offers a smart connected home solution (home automation, energy consumption optimization, security monitoring...), with a learning and predictive analysis system.< ...
# Coded from scratch, from builder to NLP, to be independent from any external programs and provide maximum data security. Messaging platforms and AI agnostic. Deployed around a solid home-made open-source core.
# Designed for non-coder users, to bring autonomy and agility to company experts.</td><td class="text-primary">Bots | Platform and Tools, Bots | Professional, AI as a Service, Agents | Platform / Tools</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="1">1 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="orelia"> <a class="text-primary" href="http://www.orelia.fr"> Orelia </a></td><td>ORELIA develops solutions (software + hardware) for audio analysis and detection, including solutions enabling industrials to integrate ad-hoc audio analysis in their products.</td><td class="text-primary">City / Infrastructures, Enterprise, Government and Military, Internet of Things, Manufacturing / Logistics, Software</td><td class="font-bold text-primary text-uppercase">2007</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="otosense"> <a class="text-primary" href="http://otosense.com"> Otosense </a></td><td>OtoSense is an infrastructure software company, offering sound recognition platform for enterprises to build value through sound intelligence.</td><td class="text-primary">Platform | Audio</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="1.2">1.2 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="ottspott"> <a class="text-primary" href="http://ottspott.co/"> Ottspott </a></td><td>Ottspott integrates with your Slack channel and creates a local phone number that can be used with clients for both in and outbound calls.</td><td class="text-primary">Enterprise</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="owi"> <a class="text-primary" href="http://owi-tech.com/fr/accueil/"> OWI </a></td><td>Artificial intelligence to understand the natural language of your customer and to automate tasks in your customer service with no added value.</td><td class="text-primary">Bots | Professional, Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="owkin"> <a class="text-primary" href="http://www.owkin.com"> Owkin </a></td><td>OWKIN builds algorithms that can interpret omics, visual data, biostatistics and patient profiles, to accelerate drug discovery and precision medicine.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="ownpage technology"> <a class="text-primary" href="http://www.ownpage.fr/"> Ownpage Technology </a></td><td>Ownpage Technology offers personalization solutions for publishers.</td><td class="text-primary">Media</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="oyst"> <a class="text-primary" href="http://www.oyst.com/"> Oyst </a></td><td>Oyst wants to make e-merchant and e-shopper's life easier by enabling users to buy in 1-click all over the web</td><td class="text-primary">Advertising and AdTech, Enterprise | Sales and Marketing, Enterprise | Security and Fraud, E-Commerce, Payment</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="3">3 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="partnering robotics"> <a class="text-primary" href="https://partnering-robotics.com/"> Partnering Robotics </a></td><td>Partnering Robotics develops robotics solution for public paces from security robots to air purifier ones.</td><td class="text-prim ...
# Traaser is a spin-off of the CEA located at Genopole and laureate of the "Concours mondial de l’innovation"</td><td class="text-primary">AI as a Service</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="1">1 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="twinswheel"> <a class="text-primary" href="http://www.twinswheel.fr/"> TwinswHeel </a></td><td>Twinswheel is developing an autonomous parcel delivery droid for the future of last mile urban delivery</td><td class="text-primary">Manufacturing / Logistics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="ubiant"> <a class="text-primary" href="http://www.ubiant.com/"> Ubiant </a></td><td>Ubiant has developed Hemis (Home Energy Management Intelligent System), a smart solution for superior energy efficiency.</td><td class="text-primary">Connected home</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="7">7 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="uchidata"> <a class="text-primary" href="http://uchidata.com/"> Uchidata </a></td><td>Uchidata is a Text-Mining API which makes it easy to analyze, classify and tag texts in real time.</td><td class="text-primary">Platform | Natural Language</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="vade secure"> <a class="text-primary" href="http://www.vadesecure.com"> Vade Secure </a></td><td>Vade Secure is an email security provider, serving400M mailboxes through Internet Service Providers, hosting companies, OEM Agreement with companies like Cisco, Microsoft and also enterprises.</td><td class="text-primary">Science and Engineering, Security</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="15">15 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="vekia"> <a class="text-primary" href="http://www.vekia.fr/"> Vekia </a></td><td>Vekia developed predictive planning software that uses the latest advances in research to model the complex problems of supply chains.</td><td class="text-primary">Manufacturing / Logistics</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase" data-order="17.03">17.03 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="verteego"> <a class="text-primary" href="http://www.verteego.com"> Verteego </a></td><td>Verteego designs and provides smart data management solutions combining prescriptive analytics with Business, Economic, Environment, Social, Governance information expertise.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr><td class="font-bold text-uppercase" data-order="viavoo"> <a class="text-primary" href="http://viavoo.com"> viavoo </a></td><td>Viavoo provides sentiment and text analytics software for customer feedback.</td><td class="text-primary">Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="2">2 M$</td></tr><tr><td class="font-bold text-uppercase" data-order="visualbot.ai"> <a class="text-primary" href="http://visualbot.ai"> Visualbot.ai </a></td><td>Visualbot is an AI enabled customer experience solution tailored for retailers (AI powered customer assistant) that includes 30 packaged, tested and trained conversational scenarios that are constantly improved.</td><td class="text-primary">Bots | Platform and Tools</td><td class="font-bold text-primary text ...
# Zyl is the first AI-powered photo app that relives your best photos and helps you re-engage with your friends.</td><td class="text-primary">Consumer app, Machine Learning</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="0.15">0.15 M$</td></tr></tbody></table></div></div></div></section><section><div class="cta bg-cover bg-fixed pos-rlt has-bg" style="background-color: #062048;"> <img class="pos-abt h-full bg-left" src="https://franceisai.com/wp-content/uploads/bg-particules-2-reverse-1.png" alt="" /><img class="pos-abt h-full bg-right" src="https://franceisai.com/wp-content/uploads/bg-particules-2-1.png" alt="" /><div class="_pit-section  normal"><div class="section-menu-padding"></div><div class="section-introduction"><div class="container"><h1>We are an initiative powered by volunteers, join us to support the ecosystem</h1> <a target="" href="https://franceisai.com/get-involved" class="btn plain white primary">Get involved<i class="fa fa-long-arrow-right m-l-6"></i></a></div></div></div></div></section><footer class="section-footer"><div class="section-personal-info p-y-10"><div class="container d-flex w-full flex-column flex-sm-row justify-content-center"><div class="col-12 col-sm-6 col-md-3 text-center"> <img src="https://franceisai.com/wp-content/uploads/photo-portrait.png" alt=""></div><div class="col-12 col-sm-6 col-md-3"><div class="personal-name"><h2>Damien Gromier</h2></div><div class="personal-role"><p class="p1"><span style="color: #0d64eb; text-transform: uppercase;"><b>Président @ France Is Ai</b></span></p> <a target="_blank" href="https://www.linkedin.com/in/damien-gromier-862a0426/"><i class="fa fa-linkedin-square"></i></a></div> <a class="btn plain primary m-b-6" href="https://franceisai.com/contact">Contact me<i class="fa fa-long-arrow-right m-l-6"></i></a> <a class="btn outline primary" href="https://franceisai.com/about-us">or learn more about us<i class="fa fa-long-arrow-right m-l-6"></i></a></div></div></div><div class="footer-bottom p-y-10"><div class="container d-flex justify-content-center align-items-center flex-column"><div class="footer-menu m-b-6"><ul id="menu-menu-footer" class="nav-footer-menu m-t-lg d-flex flex-column flex-sm-row justify-content-center"><li id="menu-item-474" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-474"><a href="https://franceisai.com/about-us">About us</a></li><li id="menu-item-475" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-475"><a href="#">Ressources</a></li><li id="menu-item-2370" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2370"><a href="https://franceisai.com/contact">Contact us</a></li></ul></div><div class="footer-information m-b-6"><div class="social-network-container d-flex"><div class="text-center social-network"> <a href="https://www.facebook.com/FranceisAI/" target="_blank"> <i class="fa fa-fw fa-lg fa-facebook"></i> </a></div><div class="text-center social-network"> <a href="https://twitter.com/franceisai" target="_blank"> <i class="fa fa-fw fa-lg fa-twitter"></i> </a></div><div class="text-center social-network"> <a href="https://www.linkedin.com/groups/8592074" target="_blank"> <i class="fa fa-fw fa-lg fa-linkedin"></i> </a></div></div></div><div class="footer-credits"><p> <a href="https://franceisai.com">France is AI</a> - Copyright 2018 - Legal notice</p></div></div></div></footer><link rel='stylesheet' id='basecss-css' href='https://franceisai.com/wp-content/plugins/eu-cookie-law/css/style.css?ver=4.9.5' type='text/css' media='all' /> <script type='text/javascript'>/* <![CDATA[ */ var eucookielaw_data = {"euCookieSet":null,"autoBlock":"0","expireTimer":"180","scrollConsent":"0","networkShareURL":"","isCookiePage":"","isRefererWebsite":"","deleteCookieUrl":"https:\/\/franceisai.com\/startup\/goshaba-2?nocookie=1"}; /* ]]> */</script> <script type='text/javascript' src='https://franceisai.com/wp ...
