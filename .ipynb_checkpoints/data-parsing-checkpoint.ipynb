# %%
# !pip install beautifulsoup4
# Out:
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("FranceAI.htm", 'html.parser')

print(soup.prettify())
# Out:
# FranceAI.htm
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:219: UserWarning: "b'FranceAI.htm'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
def main():
    f= open("FranceAI.htm", "r")
    if f.mode == "r":
        contents = f.read()
        print(contents)
        
if _ _name_ _=="_ _main_ _"
man()
# Out:
#   File "<ipython-input-8-b8f9eae2c838>", line 7
#     if _ _name_ _=="_ _main_ _"
#               ^
# SyntaxError: invalid syntax

# %%
file = open("FraneAI.htm", "r")
print file.read()
# Out:
#   File "<ipython-input-9-1fbae29d8a71>", line 2
#     print file.read()
#              ^
# SyntaxError: invalid syntax

# %%
html_ai = """
<!DOCTYPE html>
<!-- saved from url=(0031)https://franceisai.com/startups -->
<html lang="fr-FR" prefix="og: http://ogp.me/ns#" class="gr__franceisai_com"><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"> <script type="text/javascript" async="" src="./France-is-AI_files/analytics.js"></script><script async="" src="./France-is-AI_files/gtm.js"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
		})(window,document,'script','dataLayer','GTM-M97KFNW');</script> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta name="mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-title" content="France is AI - Description"><meta name="theme-color" content="#F7F7F7"><title>French startups players in Artificial Intelligence- France is AI</title><meta name="description" content="Discover many French startups leveraging AI in a variety of applications that boosted the ecosystem in France. France is AI draws startups that are players in Artificial Intelligence, the ecosystem."><link rel="canonical" href="https://franceisai.com/startups"><link rel="next" href="https://franceisai.com/startups/page/2"><meta property="og:locale" content="fr_FR"><meta property="og:type" content="object"><meta property="og:title" content="French startups players in Artificial Intelligence- France is AI"><meta property="og:url" content="https://franceisai.com/startups"><meta property="og:site_name" content="France is AI"><meta name="twitter:card" content="summary_large_image"><meta name="twitter:description" content="Discover many French startups leveraging AI in a variety of applications that boosted the ecosystem in France. France is AI draws startups that are players in Artificial Intelligence, the ecosystem."><meta name="twitter:title" content="French startups players in Artificial Intelligence- France is AI"><link rel="dns-prefetch" href="https://cdn.datatables.net/"><link rel="dns-prefetch" href="https://cdnjs.cloudflare.com/"><link rel="dns-prefetch" href="https://maps.googleapis.com/"><link rel="dns-prefetch" href="https://fonts.googleapis.com/"><link rel="dns-prefetch" href="https://s.w.org/"><link rel="alternate" type="application/rss+xml" title="France is AI » Flux" href="https://franceisai.com/feed"><link rel="alternate" type="application/rss+xml" title="France is AI » Flux des commentaires" href="https://franceisai.com/comments/feed"><link rel="alternate" type="application/rss+xml" title="France is AI » Flux pour Startup" href="https://franceisai.com/startups/feed/"><style type="text/css">img.wp-smiley,img.emoji{display:inline!important;border:none!important;box-shadow:none!important;height:1em!important;width:1em!important;margin:0 .07em!important;vertical-align:-0.1em!important;background:none!important;padding:0!important}</style><link rel="stylesheet" id="_pit-datatables-css" href="./France-is-AI_files/jquery.dataTables.min.css" type="text/css" media="all"><link rel="stylesheet" id="_pit-css-css" href="./France-is-AI_files/style.css" type="text/css" media="all"><link rel="stylesheet" id="_pit-css-default-css" href="./France-is-AI_files/style(1).css" type="text/css" media="all"><link rel="stylesheet" id="_pit-slick_style-css" href="./France-is-AI_files/slick.css" type="text/css" media="all"><link rel="stylesheet" id="_pit-slick_style_theme-css" href="./France-is-AI_files/slick-theme.css" type="text/css" media="all"><link rel="stylesheet" id="_pit-font-source-sans-css" href="./France-is-AI_files/css" type="text/css" media="all"><link rel="stylesheet" id="_pit-font-josefin-sans-css" href="./France-is-AI_files/css(1)" type="text/css" media="all"><link rel="stylesheet" id="af-form-style-css" href="./France-is-AI_files/form.css" type="text/css" media="all"> <script type="text/javascript" src="./France-is-AI_files/jquery.js"></script> <script type="text/javascript" src="./France-is-AI_files/jquery-migrate.min.js"></script> <script type="text/javascript" src="./France-is-AI_files/aos.js"></script> <script type="text/javascript" src="./France-is-AI_files/bootstrap.min.js"></script> <script type="text/javascript" src="./France-is-AI_files/datepicker.js"></script> <script type="text/javascript" src="./France-is-AI_files/longue-vue.js"></script> <script type="text/javascript" src="./France-is-AI_files/slick.min.js"></script> <script type="text/javascript" src="./France-is-AI_files/svg.js"></script> <script type="text/javascript" src="./France-is-AI_files/functions.js"></script> <script type="text/javascript" src="./France-is-AI_files/global.js"></script> <script type="text/javascript" src="./France-is-AI_files/menu.js"></script> <script type="text/javascript">/* <![CDATA[ */ var ajaxurl = "https:\/\/franceisai.com\/connect-in\/admin-ajax.php"; /* ]]> */</script> <script type="text/javascript" src="./France-is-AI_files/ajax.js"></script> <script type="text/javascript" src="./France-is-AI_files/ajax-af-form.js"></script> <script type="text/javascript" src="./France-is-AI_files/jquery.dataTables.min.js"></script> <script type="text/javascript" src="./France-is-AI_files/dataTables.responsive.min.js"></script> <script type="text/javascript" src="./France-is-AI_files/bootstrap-table.min.js"></script> <script type="text/javascript" src="./France-is-AI_files/js"></script> <script type="text/javascript" src="./France-is-AI_files/google-map.js"></script> <link rel="https://api.w.org/" href="https://franceisai.com/wp-json/"><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://franceisai.com/xmlrpc.php?rsd"><link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://franceisai.com/wp-includes/wlwmanifest.xml"><meta name="generator" content="WordPress 4.9.5"><link rel="icon" href="https://franceisai.com/wp-content/uploads/capture-decran-2018-01-14-a-19-55-31.png" sizes="32x32"><link rel="icon" href="https://franceisai.com/wp-content/uploads/capture-decran-2018-01-14-a-19-55-31.png" sizes="192x192"><link rel="apple-touch-icon-precomposed" href="https://franceisai.com/wp-content/uploads/capture-decran-2018-01-14-a-19-55-31.png"><meta name="msapplication-TileImage" content="https://franceisai.com/wp-content/uploads/capture-decran-2018-01-14-a-19-55-31.png"><style type="text/css" id="GINGER_SOFTWARE_style">.GINGER_SOFTWARE_noMark { background : transparent; }  .GINGER_SOFTWARE_wrapper{ position: absolute; overflow: hidden; margin: 0px; padding: 0px; border: 0px solid transparent } .GINGER_SOFTWARE_contour { position : absolute; margin: 0px; }  .GINGER_SOFTWARE_richText { margin : 0px; padding-bottom: 3px; border-width: 0px; border-color: transparent; display: block; color: transparent; -webkit-text-fill-color: transparent; overflow: hidden; white-space: pre-wrap;}  .GINGER_SOFTWARE_inputWrapper .GINGER_SOFTWARE_richText {position: absolute;}  .GINGER_SOFTWARE_canvas { display:none; background-repeat:no-repeat;}  .GINGER_SOFTWARE_control .GINGER_SOFTWARE_correct, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_SpellingCorrect, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_spelling, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_mark {border-top-left-radius:2px; border-top-right-radius:2px; border-bottom-right-radius:2px; border-bottom-left-radius:2px;} .GINGER_SOFTWARE_control .GINGER_SOFTWARE_correct, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_SpellingCorrect, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_spelling, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_mark {background-image:url(data:image/gif;base64,...)!important;} .GINGER_SOFTWARE_control .GINGER_SOFTWARE_correct.GINGER_SOFTWARE_synonym, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_SpellingCorrect.GINGER_SOFTWARE_synonym, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_spelling.GINGER_SOFTWARE_synonym, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_mark.GINGER_SOFTWARE_synonym {background-image:url(data:image/gif;base64,...)!important;} .GINGER_SOFTWARE_control .GINGER_SOFTWARE_correct.GINGER_SOFTWARE_noSuggestion, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_SpellingCorrect.GINGER_SOFTWARE_noSuggestion, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_spelling.GINGER_SOFTWARE_noSuggestion, .GINGER_SOFTWARE_control .GINGER_SOFTWARE_mark.GINGER_SOFTWARE_noSuggestion {background-image:url(data:image/gif;base64,...)!important;} .GINGER_SOFTWARE_richText .GINGER_SOFTWARE_correct, .GINGER_SOFTWARE_richText .GINGER_SOFTWARE_SpellingCorrect, .GINGER_SOFTWARE_richText .GINGER_SOFTWARE_spelling, .GINGER_SOFTWARE_richText .GINGER_SOFTWARE_mark {position:relative; background-image:none!important;} .GINGER_SOFTWARE_richText .GINGER_SOFTWARE_markHighlightLeft { position : absolute; left:-2px; top:0px; bottom:0px; width:2px;} .GINGER_SOFTWARE_richText .GINGER_SOFTWARE_markHighlightRight { position : absolute; right:-2px; top:0px; bottom:0px; width:2px;} .GINGER_SOFTWARE_richText .GINGER_SOFTWARE_markHighlightTop { position : absolute; left:0px; right:0px; top:-2px; height:3px;} .GINGER_SOFTWARE_richText .GINGER_SOFTWARE_markHighlightBottom { position : absolute; left:0px; right:0px; bottom:-2px; height:3px;}</style><script type="text/javascript" charset="UTF-8" src="./France-is-AI_files/common.js"></script><script type="text/javascript" charset="UTF-8" src="./France-is-AI_files/util.js"></script><script type="text/javascript" charset="UTF-8" src="./France-is-AI_files/stats.js"></script></head><body class="archive post-type-archive post-type-archive-startup" data-gr-c-s-loaded="true" ginger_software_stylesheet="true" ginger_software_doc="true"><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-M97KFNW"
height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><header><nav class="menu menu-me menu-scroll"> <input type="checkbox" id="toggle"><ul><li class="logo"><a href="https://franceisai.com/"><img src="./France-is-AI_files/france-is-ai-logo-startup.png" alt="France is AI" title="France is AI" class="img-responsive"></a></li><li class="burger"><label for="toggle"><span></span></label></li><li id="menu-item-2513" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2513"><a href="https://franceisai.com/startups#">Conferences</a><ul class="sub-menu"><li id="menu-item-612" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-612"><a href="https://franceisai.com/conferences/conference-2017">Conference 2017</a></li><li id="menu-item-2572" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2572"><a href="http://ai-night.com/">AI Night 2018</a></li></ul></li><li id="menu-item-2320" class="menu-item menu-item-type-post_type_archive menu-item-object-startup current-menu-item menu-item-2320"><a href="https://franceisai.com/startups">Startups</a></li><li id="menu-item-2321" class="menu-item menu-item-type-post_type_archive menu-item-object-research-center menu-item-2321"><a href="https://franceisai.com/research">Research</a></li><li id="menu-item-462" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-462"><a href="https://franceisai.com/education">Education</a></li><li id="menu-item-2322" class="menu-item menu-item-type-post_type_archive menu-item-object-community menu-item-2322"><a href="https://franceisai.com/community">Community</a></li><li id="menu-item-2323" class="menu-item menu-item-type-post_type_archive menu-item-object-event menu-item-2323"><a href="https://franceisai.com/calendar">Calendar</a></li><li id="menu-item-459" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-459"><a href="https://franceisai.com/about-us">About us</a></li><li id="menu-item-458" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-458"><a href="https://franceisai.com/partners">Partners</a></li><li class="lang menu-item"><ul><li id="menu-item-674" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-674"><a href="https://franceisai.com/startups#">EN</a><ul class="sub-menu"><li id="menu-item-673" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-673"><a href="https://franceisai.com/startups#">FR</a></li></ul></li></ul></li></ul></nav></header><section><div class="cta bg-cover bg-fixed pos-rlt has-bg" style="background-color: #062048;"> <img class="pos-abt h-full bg-left" src="./France-is-AI_files/bg-particules-2-reverse-1.png" alt=""><img class="pos-abt h-full bg-right" src="./France-is-AI_files/bg-particules-2-1.png" alt=""><div class="_pit-section  normal"><div class="section-menu-padding"></div><div class="section-introduction"><div class="container"><h1>Discover 285+ French startups leveraging AI in a variety of applications</h1> <a target="" href="https://franceisai.com/startups/add-startup" class="btn plain white primary">Add your start up<i class="fa fa-long-arrow-right m-l-6"></i></a></div></div></div></div></section><section class="contenu"><div class="section-menu-padding"></div><div class="_pit-section "><div class="container"><p><img class="aligncenter size-full wp-image-2676" src="./France-is-AI_files/capture-decran-2018-04-09-a-23-41-59.png" alt="" width="1404" height="984" srcset="https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59.png 1404w, https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59-250x175.png 250w, https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59-768x538.png 768w, https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59-700x491.png 700w, https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59-120x84.png 120w, https://franceisai.com/wp-content/uploads/capture-decran-2018-04-09-a-23-41-59-500x350.png 500w" sizes="(max-width: 1404px) 100vw, 1404px"></p></div></div></section><section><div class="cta bg-cover bg-fixed pos-rlt "><div class="_pit-section  normal"><div class="section-menu-padding"></div><div class="section-introduction"><div class="container"><h1>Add your start up</h1> <a target="" href="https://franceisai.com/startups/add-startup" class="btn plain  primary">Add your start up<i class="fa fa-long-arrow-right m-l-6"></i></a></div></div></div></div></section><section class="_pit-section loop-table "><div class="section-menu-padding"></div><div class="section-introduction"><div class="container"><h4 style="text-align: center;">Start up list</h4><h2 style="text-align: center;">Find a Start up</h2></div></div><div class="section-content"><div class="container"><div id="startups-tables" class="table-responsive"><div id="table_wrapper" class="dataTables_wrapper no-footer"><div id="table_filter" class="dataTables_filter"><label>Search:<input type="search" class="" placeholder="" aria-controls="table"></label></div><table id="table" class="table dt-responsive dataTable no-footer dtr-inline" role="grid"><thead><tr role="row"><th scope="col" class="sorting_asc" tabindex="0" aria-controls="table" rowspan="1" colspan="1" aria-sort="ascending" aria-label="Company: activate to sort column descending">Company</th><th scope="col" class="sorting" tabindex="0" aria-controls="table" rowspan="1" colspan="1" aria-label="Description: activate to sort column ascending">Description</th><th scope="col" class="sorting" tabindex="0" aria-controls="table" rowspan="1" colspan="1" aria-label="Category: activate to sort column ascending">Category</th><th scope="col" class="sorting" tabindex="0" aria-controls="table" rowspan="1" colspan="1" aria-label="Founding date: activate to sort column ascending">Founding date</th><th scope="col" class="sorting" tabindex="0" aria-controls="table" rowspan="1" colspan="1" aria-label="Fundraising: activate to sort column ascending">Fundraising</th></tr></thead><tbody><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="ab tasty" tabindex="0"> <a class="text-primary" href="https://www.abtasty.com/"> AB Tasty </a></td><td>AB Tasty helps data-driven marketers tailor user-experience and increase conversion rates through A/B testing and content personalisation. A user-friendly and interactive SaaS-solution, AB Tasty makes it easier to compare different designs of a page – regardless of technical skills.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Sales and Marketing, Software, Conversion Rate Optimisation</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="6.48">6.48 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="adblock radio" tabindex="0"> <a class="text-primary" href="https://www.adblockradio.com/"> Adblock Radio </a></td><td>Adblock Radio leverages AI to enable radio listeners to skip annoying commercials</td><td class="text-primary">Advertising and AdTech, Media and Entertainment, Platforms | Audio</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="adomik" tabindex="0"> <a class="text-primary" href="http://www.adomik.com/"> Adomik </a></td><td>Adomik provides technology for digital media sellers that helps them analyze and optimize programmatic media sales.</td><td class="text-primary">AdTech</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="1.4">1.4 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="advanced track &amp; trace" tabindex="0"> <a class="text-primary" href="https://www.att-fr.com/"> Advanced Track &amp; Trace </a></td><td>Advanced Track &amp; Trace supplies industries and governments with field-proven authentication, identification, secure traceability tools and dependable third-party infrastructures against ollicit trade (counterfeiting, smuggling, over-production...).</td><td class="text-primary">Enterprise | Security and Fraud</td><td class="font-bold text-primary text-uppercase">2007</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="aimerging health" tabindex="0"> <a class="text-primary" href="http://www.aimerginghealth.com/"> AImerging Health </a></td><td>AImerging health is a software and services development company whose mission is to develop automated risk detection and prevention tools in the field of healthcare by using big data.</td><td class="text-primary">Bots | Professional, Hardware and Processing, Healthcare</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="akheros" tabindex="0"> <a class="text-primary" href="http://akheros.com/about/"> Akheros </a></td><td>Akheros is a software development lab, producing resident cybersecurity learning algorithms, which learns machines’ informational behavior in order to anticipate, detect and prevent offensive and incongruous behaviors of machine to machine interactions.</td><td class="text-primary">Security / Fraud</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="alan" tabindex="0"> <a class="text-primary" href="https://www.alan.eu/"> Alan </a></td><td>Alan is the first digital health insurance company in Europe, and the first insurance to be licensed in France since 1986. Alan is reshaping the health insurance experience with a focus on user experience and simplicity. The company will change the way you interact with the healthcare system thanks to machine-learning.</td><td class="text-primary">Healthcare, Insurance</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="13">13 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="algolia" tabindex="0"> <a class="text-primary" href="https://www.algolia.com/"> Algolia </a></td><td>Algolia provides a hosted search API that allows websites and mobile applications to increase user engagement and conversions.</td><td class="text-primary">Search</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="74.22">74.22 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="alicante" tabindex="0"> <a class="text-primary" href="http://www.alicante.fr/"> Alicante </a></td><td>Alicante has developed expertise in the fields of health and research, serving data mining projects.</td><td class="text-primary">Administrative Services, AI as a Service, Biotechnology, Healthcare, Platforms | Natural Language, Pharmacy, Therapies and Drugs</td><td class="font-bold text-primary text-uppercase">1999</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="alkemics" tabindex="0"> <a class="text-primary" href="http://www.alkemics.com/"> Alkemics </a></td><td>Alkemics provides the collaborative intelligence network which facilitates product data exchange between brands and retailers in the FMCG industry. It allows them to manage an array of product information and marketing content across the whole product lifecycle, making it available on B2B and B2C applications.</td><td class="text-primary">Retail</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="27.6">27.6 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="allure systems" tabindex="0"> <a class="text-primary" href="http://www.alluresystems.com/"> Allure Systems </a></td><td>Allure Systems has developed proprietary patented computer vision technologies enabling image production for fashion centric e-retailers and fashion brands, while reducing 30 to 40% of visual production’s costs.</td><td class="text-primary">Retail</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="3.6">3.6 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="altospam (oktey)" tabindex="0"> <a class="text-primary" href="https://www.altospam.com/"> Altospam (Oktey) </a></td><td>ALTOSPAM is an integrated SaaS software protecting your email from spams, viruses, scams and phishing. It allows companies owning at least one domain name to secure its email servers. ALTOSPAM combines 16 anti-spams technologies, 6 anti-viruses as well as other security services such as anti-relay, anti-scam, anti-phishing and protection against denial-of-service attacks.</td><td class="text-primary">Enterprise | Security and Fraud, Science and Engineering, Software, Security</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="angus.ai" tabindex="0"> <a class="text-primary" href="http://www.angus.ai/"> Angus.ai </a></td><td>Angus.ai has developed an AI platform focused on robotics, helping developers give senses to machines.</td><td class="text-primary">Platform | Vision</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="antescofo" tabindex="0"> <a class="text-primary" href="http://www.antescofo.com/"> Antescofo </a></td><td>Antescofo is a modular polyphonic Score Following system as well as a Synchronous Programming language for musical composition. Play or sing with your favourite band or ensemble together alone</td><td class="text-primary">Platforms | Audio</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="antidot" tabindex="0"> <a class="text-primary" href="http://www.antidot.net/"> Antidot </a></td><td>Antidot is a provider of search technology and information access solutions for major portals and enterprises: search engines, capture systems, data structuring and enrichment, information navigation tools, collaboration tools, monitoring tools.</td><td class="text-primary">Search</td><td class="font-bold text-primary text-uppercase">1999</td><td class="font-bold text-primary text-uppercase" data-order="3.5">3.5 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="antvoice" tabindex="0"> <a class="text-primary" href="http://www.antvoice.com/"> Antvoice </a></td><td>AntVoice provides a 360° and predictive recommendation engine which analyzes the behavior of your visitors, in real time, to offer them a customized selection of products or contents.</td><td class="text-primary">Retail, Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="3.5">3.5 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="ardans" tabindex="0"> <a class="text-primary" href="https://www.ardans.com/"> Ardans </a></td><td>Ardans is a consulting company focused on knowledge management, engineering and expertise representation.</td><td class="text-primary">AI as a Service, Knowledge Management</td><td class="font-bold text-primary text-uppercase">1999</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="arterys" tabindex="0"> <a class="text-primary" href="https://arterys.com/"> Arterys </a></td><td>Arterys introduces a platform founded on cloud computation and deep learning to revolutionize medical imaging, starting with automating cardiac analysis.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="14.2">14.2 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="artificial scan" tabindex="0"> <a class="text-primary" href="http://www.artificialscan.com/"> Artificial Scan </a></td><td>Artificial Scan provides innovative artificial intelligence solutions for computer vision applications using all available technologies in deep learning.</td><td class="text-primary">AI as a Service, Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="asgard.ai" tabindex="0"> <a class="text-primary" href="https://asgard.ai/"> asgard.ai </a></td><td>asgard.ai is developing a web platform that provides data-driven insights about technologies and their ecosystems to help companies make decisions based on data and not opinions.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="askhub" tabindex="0"> <a class="text-primary" href="https://www.askhub.io/"> AskHub </a></td><td>AI platform for the design and continuous enhancement of chatbots using natural language</td><td class="text-primary">Bots | Platform and Tools, Bots | Professional, Advertising and AdTech, AI as a Service, Content and Publishing, Enterprise | Sales and Marketing, Internet of Things, Platforms | Natural Language</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="askhub" tabindex="0"> <a class="text-primary" href="https://www.askhub.io/"> AskHub </a></td><td>AskHub transforms Open Data into conversational ressources for chatbots</td><td class="text-primary">Bots | Platform and Tools, AI as a Service</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="askr.ai" tabindex="0"> <a class="text-primary" href="https://askr.ai/"> askR.ai </a></td><td>AskR.ai is a conversational interface for Business Intelligence, that allows non tech users to directly ask (in french or in english) questions on their enterprise's data.</td><td class="text-primary">Bots | Platform and Tools, Bots | Professional, AI as a Service</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="aspertise" tabindex="0"> <a class="text-primary" href="https://www.aspertise.net/"> ASPertise </a></td><td>ASPertise provides IA, Big Data &amp; Cybersecurity services by leveraging unique cognitive skills of atypical experts (Aspergers, Autistic, Gifted).</td><td class="text-primary">AI as a Service, Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics, Enterprise | Security and Fraud, Government and Military</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="autokab" tabindex="0"> <a class="text-primary" href="http://www.autokab.com/"> Autokab </a></td><td>AutoKAB develops cutting-edge automation services for drivers assistance and full driving automation, for the commercial deployment and operation of fully and partly automated road vehicles.</td><td class="text-primary">Transportation</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="ava.me" tabindex="0"> <a class="text-primary" href="http://www.ava.me/"> Ava.me </a></td><td>Ava empowers 400M deaf &amp; hard-of-hearing people to have accessible in-person conversations, anytime, anywhere.</td><td class="text-primary">Healthcare, Platform | Audio</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="5.4">5.4 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="axyn robotics" tabindex="0"> <a class="text-primary" href="http://www.axyn.fr/en/"> Axyn Robotics </a></td><td>Axyn Robotique is robotics company focused on the design, manufacture and sale of service robots, with a first use case in the medical space.</td><td class="text-primary">Robotics, Senior Care</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="babyprogress" tabindex="0"> <a class="text-primary" href="http://babyprogress.fr/"> Babyprogress </a></td><td>Babyprogress creates softwares for childbirth simulation using medical imaging to detect and prevent difficult births or unnecessary cesarean sections.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="0.8">0.8 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="balyo" tabindex="0"> <a class="text-primary" href="http://www.balyo.com/"> Balyo </a></td><td>Balyo designs, develops and markets totally innovative handling robots. Its technology permits fleets of robots to navigate in warehouses or in factories without any additional infrastructures, transforming standard forklift trucks into standalone intelligent robots, capable of working alongside human operators.</td><td class="text-primary">Manufacturing / Logistics, Robotics</td><td class="font-bold text-primary text-uppercase">2005</td><td class="font-bold text-primary text-uppercase" data-order="13">13 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="batvoice technologies" tabindex="0"> <a class="text-primary" href="http://www.batvoice.com/"> Batvoice Technologies </a></td><td>Batvoice Technologies has developed a voice analysis technology to boost client engagement and call-center performances.</td><td class="text-primary">Platform | Audio</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="bayes impact" tabindex="0"> <a class="text-primary" href="http://www.bayesimpact.org/"> Bayes Impact </a></td><td>Bayes Impact is a nonprofit company building data science solutions to big social problems by building software systems for governments and non-profits.</td><td class="text-primary">Government</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="beebryte" tabindex="0"> <a class="text-primary" href="http://www.beebryte.com/"> BeeBryte </a></td><td>BeeBryte is leveraging artificial intelligence to get commercial buildings, factories, EV charging stations or entire eco-suburbs to consume electricity in a smarter, more efficient and cheaper way while reducing their carbon footprint.</td><td class="text-primary">City / Infrastructures</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="1.6">1.6 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="betterise healthtech" tabindex="0"> <a class="text-primary" href="http://betterise-healthtech.com/"> Betterise Healthtech </a></td><td>Betterise develops health and wellness digital platforms, with a proprietary algorithm to customize based on users' profile, background, lifestyles, desires or environment.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="beyable" tabindex="0"> <a class="text-primary" href="http://beyable.fr/"> Beyable </a></td><td>Thanks to its AI-powered on-site solutions, BEYABLE helps marketers get the best out of their existing web/mobile site traffic through real-time content personalization. Its technology allows ambitious improvements for both registered and the many anonymous visitors, leading to more customer engagement and conversions.</td><td class="text-primary">Retail, Enterprise | Marketing / Sales</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="bidmotion" tabindex="0"> <a class="text-primary" href="http://www.bidmotion.com/"> Bidmotion </a></td><td>BidMotion is a mobile ad technology company focused on simplifying and optimizing the direct response and customer acquisition processes.</td><td class="text-primary">Enterprise | Sales and Marketing</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="big datext" tabindex="0"> <a class="text-primary" href="http://big-datext.com/"> Big Datext </a></td><td>Big Datext offers a solution to analyze verbatim and open-ended answers and make them actionable.</td><td class="text-primary">AI as a Service, Enterprise | HR and Recruiting, Enterprise | Sales and Marketing, Platforms | Natural Language</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="biggerpan" tabindex="0"> <a class="text-primary" href="https://biggerpan.com/"> Biggerpan </a></td><td>Biggerpan develops a predictive artificial intelligence technology that anticipates your needs based on a contextual analysis of the web pages you browse. The company recently launched its first product Ulli, a smart mobile browser that relies on this technology to recommend relevant content and actions for people to browse next.</td><td class="text-primary">Media and Entertainment, Platforms | Natural Language, Search</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="0.6">0.6 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="bime analytics" tabindex="0"> <a class="text-primary" href="http://bimeanalytics.com/"> BIME Analytics </a></td><td>BIME is a powerful modern BI tool capable of turning data from any source into valuable insights and actionable information.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="5">5 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="bioserenity" tabindex="0"> <a class="text-primary" href="http://www.bioserenity.com/"> BioSerenity </a></td><td>BioSerenity has developed a sensor and an algorithm for the automatic detection and prediction of Epileptic Seizures</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="3.3">3.3 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="bluefrog robotics" tabindex="0"> <a class="text-primary" href="http://www.bluefrogrobotics.com/"> Bluefrog robotics </a></td><td>Blue Frog Robotics is the developer of BUDDY, a Social Robot.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="botfuel.io" tabindex="0"> <a class="text-primary" href="http://www.botfuel.io/"> Botfuel.io </a></td><td>Botfuel is a chatbot platform that connects companies data to almost any messaging app, with an SDK enabling developers and companies to build enterprise-ready bots.</td><td class="text-primary">Agents | Professional</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="brainwave" tabindex="0"> <a class="text-primary" href="https://www.brainwavegrc.com/"> Brainwave </a></td><td>Brainwave GRC is a software vendor focused on Identity Analytics and intelligence, to help companies to fight against cyber risks, detect insider threats, attacks, and fraud with innovative GRC solutions.</td><td class="text-primary">Enterprise | Big Data and Analytics, Enterprise | Security and Fraud</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase" data-order="3.28">3.28 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="brennus analytics" tabindex="0"> <a class="text-primary" href="http://www.brennus.tech/"> Brennus Analytics </a></td><td>Brennus Analytics develops a price optimization solution focused on B2B sales.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="c3 iot" tabindex="0"> <a class="text-primary" href="https://c3iot.com/"> C3 IoT </a></td><td>C3 IoT delivers a complete platform as a service for rapidly developing and operating big data, predictive analytics, AI, and IoT software applications.</td><td class="text-primary">AI as a Service, Enterprise, Enterprise | Big Data and Analytics, Internet of Things, Platforms | Big Data, Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="220">220 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="calldesk" tabindex="0"> <a class="text-primary" href="http://www.calldesk.ai/"> Calldesk </a></td><td>CallDesk is an artificial intelligence based virtual secretary, autonomously handling phone conversations focused on call centers.</td><td class="text-primary">Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="carbon bee" tabindex="0"> <a class="text-primary" href="http://carbonbee.fr/"> Carbon Bee </a></td><td>Carbon Bee develops sensors and diagnostics tool to monitor vegetal health.</td><td class="text-primary">Agriculture and Farming, AI as a Service, Internet of Things, Robotics, Search, Science and Engineering, Software</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="cardiologs" tabindex="0"> <a class="text-primary" href="http://www.cardiologs.com/"> Cardiologs </a></td><td>CardioLogs allows healthcare professionals to accurately and reliably screen their patients for heart disorders, leveraging its EKG reading proprietary technology.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="1.7">1.7 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="carfit" tabindex="0"> <a class="text-primary" href="http://www.car.fit/"> Carfit </a></td><td>Carfit leverages the automotive vibration science [NVH] with AI to anticipate maintenance needs.</td><td class="text-primary">Internet of Things, Transportation</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="2.23">2.23 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="cartesiam" tabindex="0"> <a class="text-primary" href="http://www.cartesiam.com/"> Cartesiam </a></td><td>Cartesian brings cognitive capabilities (hardware and software) into sensors to enable the decision power on the edges.</td><td class="text-primary">City / Infrastructures, Enterprise, Internet of Things, Hardware/Processing</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="0.85">0.85 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="churnspotter / predicsis" tabindex="0"> <a class="text-primary" href="https://churnspotter.io/"> Churnspotter / Predicsis </a></td><td>Predicsis provides state-of-the art automatic Predictive Analytics solutions to increase Customer Lifetime value. Their product ChurnSpotter helps SaaS and mobile apps vendors reduce their user and revenue churn.</td><td class="text-primary">Enterprise | Marketing / Sales</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="1.8">1.8 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="citron" tabindex="0"> <a class="text-primary" href="http://www.meetcitron.com/"> Citron </a></td><td>Conversational intelligence (ChatBot) that recommends places to go to.</td><td class="text-primary">Bots | Personal, AI as a Service, Food and Beverage</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="clustaar" tabindex="0"> <a class="text-primary" href="http://www.clustaar.com/"> Clustaar </a></td><td>Clustaar built a conversation engine for chatbots and robots.</td><td class="text-primary">Agents | Professional</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="clustree" tabindex="0"> <a class="text-primary" href="http://www.clustree.com/en/"> Clustree </a></td><td>Clustree is a Big Data driven decision making solution for Talent Management.</td><td class="text-primary">Enterprise | HR / Recruiting</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="11.55">11.55 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="cogiflex" tabindex="0"> <a class="text-primary" href="https://www.cogiflex.com/"> Cogiflex </a></td><td>Cogiflex develops an artificial intelligence assistant to help anyone to learn whatever her/his age and level</td><td class="text-primary">AI as a Service, Education</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="0.15">0.15 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="cognitalk" tabindex="0"> <a class="text-primary" href="http://www.cognitalk.com/"> CogniTalk </a></td><td>CogniTalk develops intelligent and knowledgeable conversational agents.</td><td class="text-primary">Bots | Personal, Bots | Professional, Platforms | Natural Language</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="0.42">0.42 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="collective-thinking.com" tabindex="0"> <a class="text-primary" href="http://collective-thinking.com/"> Collective-thinking.com </a></td><td>Collective Thinking is specialized in the analysis of large amounts of qualitative data (views and opinions related to a topic, a product or a service, company data, …) and machine learning (recommender systems, etc. .).</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="comet" tabindex="0"> <a class="text-primary" href="https://cometapp.io/"> Comet </a></td><td>Comet is the first Artificial Intelligence powered photo app that manages your photos for you, and with you.</td><td class="text-primary">Consumer app</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="0.25">0.25 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="commoprices" tabindex="0"> <a class="text-primary" href="https://commoprices.com/fr"> CommoPrices </a></td><td>CommoPrices is a business intelligence solution helping companies track over 3000 commodity prices.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="0.1">0.1 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="compareagences" tabindex="0"> <a class="text-primary" href="http://www.compareagences.com/"> CompareAgences </a></td><td>CompareAgences is a real estate agency comparison platform, aiming at improving user experience when selecting a broker.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="cosmo company" tabindex="0"> <a class="text-primary" href="https://cosmotech.com/"> CoSMo Company </a></td><td>The CoSMo Company is a technology company that helps the C-suite make optimal decisions with a unique methodology to extract value from complexity and provide the C-suite with the interconnected insights.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="8.8">8.8 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="craft.ai" tabindex="0"> <a class="text-primary" href="http://craft.ai/"> Craft.ai </a></td><td>Craft Ai provides AI-as-a-service for Mobile, Web and IoT. craft ai enables developers to bring awareness and learning to their apps.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="1.11">1.11 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="customermatrix" tabindex="0"> <a class="text-primary" href="http://www.customermatrix.com/"> CustomerMatrix </a></td><td>CustomerMatrix offers a market-leading Cognitive Computing platform that helps B2B companies capture hidden revenue opportunities in real-time, by recommending specific actions for customer-facing employees and placing recommendations in their existing workflows, ranked by impact value.</td><td class="text-primary">Enterprise | Marketing / Sales</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="16">16 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="cutii" tabindex="0"> <a class="text-primary" href="https://www.cutii.io/"> Cutii </a></td><td>Cutii is an interactive platform between isolated or dependent people and their families or a community of individuals, caregivers, associations and doctors. The access to a large range of activities and services preserve the daily joie de vivre. Regarding the Cutiiz, they will share their passion and savoir-faire with them.</td><td class="text-primary">Bots | Platform and Tools, AI as a Service, Connected home, Healthcare, Robotics</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="1.2">1.2 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="cybelangel" tabindex="0"> <a class="text-primary" href="https://www.cybelangel.com/"> CybelAngel </a></td><td>CybelAngel threats intelligence solution is designed to detect data leaks on the internet.</td><td class="text-primary">Enterprise | Security / Fraud</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="1.11">1.11 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="cypheme" tabindex="0"> <a class="text-primary" href="http://www.cypheme.com/"> Cypheme </a></td><td>Cypheme is a smartphone-based anti-counterfeit system, combining microstructured paper tags and a mobile app using machine-learning powered pattern-recognition</td><td class="text-primary">Enterprise | Security / Fraud</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="1.32">1.32 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="daco" tabindex="0"> <a class="text-primary" href="http://www.daco.io/"> daco </a></td><td>daco helps retailers and brands benchmark their competitors with an unparalleled level of granularity.
Our high-end strategic tools based on Deep Learning and Image recognition allow retailers to industrialize their benchmarking activities and align billions of products on their taxonomy. Our company was founded by former strategy consultants and data experts, and also offers customized, cutting-edge predictive solutions to retail leaders in France and abroad.</td><td class="text-primary">AI as a Service, Clothing and Apparel, Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics, Platforms | Vision, Platforms | Big Data, Retail, Enterprise | Business + Predictive Intelligence, Big Data / Machine Learning, E-Commerce, Machine Learning</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="databerries" tabindex="0"> <a class="text-primary" href="http://www.databerries.com/"> Databerries </a></td><td>DataBerries offers performance mobile marketing campaigns powered by machine learning algorithms.</td><td class="text-primary">AdTech</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="17.86">17.86 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="dataiku" tabindex="0"> <a class="text-primary" href="http://www.dataiku.com/"> Dataiku </a></td><td>Dataiku develops Data Science Studio, the tool that lets data scientists and analysts do machine learning on any (dirty) data.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="45.7">45.7 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="datananas" tabindex="0"> <a class="text-primary" href="https://www.datananas.com/"> Datananas </a></td><td>Datananas builds B2B prospect lists from professional social networks to generate new Outbound leads without cold calling.</td><td class="text-primary">Enterprise | Sales and Marketing, Software</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="datapred" tabindex="0"> <a class="text-primary" href="http://www.datapred.com/"> Datapred </a></td><td>Datapred provides a cutting-edge algorithmic engine that helps businesses take advantage of the huge amounts of data they generate and that surround them.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="datapublica / c-radar" tabindex="0"> <a class="text-primary" href="http://www.c-radar.com/"> DataPublica / C-Radar </a></td><td>C-Radar is a B2B predictive marketing platform that helps identify new potential customers.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="dataswati" tabindex="0"> <a class="text-primary" href="http://dataswati.com/"> Dataswati </a></td><td>Dataswati develops PowerOp, an AI to improve industrial processes and boost factory output based on various datasources (sensors, images, written reports and procedures).</td><td class="text-primary">AI as a Service, Manufacturing / Logistics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="davi" tabindex="0"> <a class="text-primary" href="http://www.davi.ai/"> DAVI </a></td><td>DAVI has developed a Digital Agent solution leveraging 3D animation engine and Natural Language Processing (NLP), to transform the digital relationship into a human relationship.</td><td class="text-primary">Agents | Platform / Tools</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="dawex" tabindex="0"> <a class="text-primary" href="https://www.dawex.com/"> Dawex </a></td><td>Dawex is a data marketplace to securely and efficiently buy, sell and exchange data directly, for any industry, anywhere in the world.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="2.23">2.23 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="dcbrain" tabindex="0"> <a class="text-primary" href="http://www.dcbrain.com/"> DCbrain </a></td><td>DCbrain is a solution based on graphe models and Machine Learning used to ease exploitation and maintenance processes of complex industrial networks (such as gas, water, electricity, logistic,...).</td><td class="text-primary">City / Infrastructures</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="1.84">1.84 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="deep flow realty" tabindex="0"> <a class="text-primary" href="https://www.deep-flow-realty.com/"> Deep Flow Realty </a></td><td>Deep Flow Realty develops an NLP solution to help real estate brokers be more productive.</td><td class="text-primary">AI as a Service, Platforms | Natural Language, Professional Services, Real Estate and Construction</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="deepomatic" tabindex="0"> <a class="text-primary" href="http://www.deepomatic.com/"> Deepomatic </a></td><td>Deepomatic builds computer vision solutions to help companies tackle detection, classification and visual recognition tasks. Their dataset building platform can be used in synergy with human workforce to solve the most complex problems, ranging from security and e-commerce to food industry and autonomous vehicles.</td><td class="text-primary">Platform | Vision</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="2.3">2.3 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="deepor" tabindex="0"> <a class="text-primary" href="http://www.deepor.ai/"> DeepOR </a></td><td>DeepOR is a powerful platform to monitor and optimize the use of Hospital Operating Rooms (ORs). It offers advanced features based on Big Data and Computer Vision to help make real-time resource allocation decisions. DeepOR's target is to improve the quality of healthcare delivery and increase financial outcomes for a hospital.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="delair-tech" tabindex="0"> <a class="text-primary" href="http://www.delair-tech.com/"> Delair-Tech </a></td><td>Delair-Tech, a leader in professional UAVs, provides aerial-imagery-based data to help industries make informed decisions.</td><td class="text-primary">Platforms | Vision, Real Estate and Construction, Robotics</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="14.5">14.5 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="dessia technologies" tabindex="0"> <a class="text-primary" href="https://dessia.tech/"> DessIA Technologies </a></td><td>DessIA is a platform based on AI to help mechanical engineers to design their product. Dessia allow to define a solution from the white sheet to the detail drawing. Our artificial intelligence analyses all the possibility for a given mechanical challenge.</td><td class="text-primary">Manufacturing / Logistics, Science and Engineering, Transportation</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="dexstr.io" tabindex="0"> <a class="text-primary" href="http://dexstr.io/"> Dexstr.io </a></td><td>DEXSTR enables a translational vision of the Life Science research activities, by providing solutions to manage and analyze vast quantities of data.</td><td class="text-primary">Healthcare, Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="dhatim" tabindex="0"> <a class="text-primary" href="http://www.dhatim.com/"> Dhatim </a></td><td>Conciliator, Dhatim Digital Assistant, optimises cost and processes for Procurement, RH and Finance with Artificial Intelligence</td><td class="text-primary">Conciliator, Dhatim Digital Assistant, optimises cost and processes for Procurement, RH and Finance with Artificial Intelligence</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase" data-order="3">3 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="dialoog" tabindex="0"> <a class="text-primary" href="http://dialoog.fr/"> Dialoog </a></td><td>Dialoog offers a solution to enhance corporate conferences, training and employee engagement by summarizing answers to open questions live.</td><td class="text-primary">Enterprise | HR / Recruiting</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="dibotics" tabindex="0"> <a class="text-primary" href="http://dibotics.com/"> Dibotics </a></td><td>Dibotics provides the key components to build a mobile robot or Autonomous Car. Real-time &amp; precise GPS-less Localization, 3D Mapping, Detection &amp; tracking of moving objects and Segmentation.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="dictanova" tabindex="0"> <a class="text-primary" href="http://www.dictanova.com/"> Dictanova </a></td><td>Dictanova has developed a text analytics and sentiment analysis cloud based platform, for customer feedback analysis purpose.</td><td class="text-primary">Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="1.28">1.28 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="do you dream up" tabindex="0"> <a class="text-primary" href="http://www.doyoudreamup.com/"> Do You Dream Up </a></td><td>Do You Dream Up is an IT and software design company that specializes in developing self-help solutions for company websites.</td><td class="text-primary">Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="doctrine" tabindex="0"> <a class="text-primary" href="https://www.doctrine.fr/"> Doctrine </a></td><td>Doctrine.fr focuses on legal research, offering a fast, efficient and user-centered search engine on the French and European case law.</td><td class="text-primary">Legal</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="2.21">2.21 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="dreamquark" tabindex="0"> <a class="text-primary" href="http://www.dreamquark.com/"> Dreamquark </a></td><td>DreamQuark uses and develops state of the art artificial intelligence and machine-learning technologies in order to bring to Insurance and Healthcare the latest developments in perception and analytics and their combination: User interaction during subscription and sinister declaration, Fraud detection, Customer relationship, Prevention, Risk management, Customer knowledge.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="0.4">0.4 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="dreamup vision" tabindex="0"> <a class="text-primary" href="http://www.dreamupvision.com/"> DreamUp Vision </a></td><td>DreamUp VIsion fights blindness by providing healthcare professionals everywhere around the world with software that diagnoses blindness related diseases, misdiagnosed due to lack of ophthalmologists.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="early birds" tabindex="0"> <a class="text-primary" href="http://www.early-birds.fr/en/index.html"> Early Birds </a></td><td>Early Birds provides a predictive recommendation engine which analyzes in real-time the behavior of visitors on all digital devices, in order to optimize and personalize the customer journey and recommend the right offer at the right time.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Sales and Marketing, Retail</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="0.51">0.51 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="easymile" tabindex="0"> <a class="text-primary" href="http://www.easymile.com/"> EasyMile </a></td><td>EasyMile's ambition is to reclaim the city for the people, and develops autonomous transportation systems for the last mile to achieve that goal</td><td class="text-primary">City / Infrastructures, Transportation</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="14.93">14.93 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="elum energy" tabindex="0"> <a class="text-primary" href="http://www.elum-energy.com/"> Elum Energy </a></td><td>Elum develops a software that optimizes energy between solar panels, batteries and the grid in order to reduce the energy bill for industrial and commercial building.</td><td class="text-primary">City / Infrastructures, Energy</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="endocontrol" tabindex="0"> <a class="text-primary" href="http://www.endocontrol-medical.com/"> Endocontrol </a></td><td>Endocontrol specializes in robotic assistance for laparoscopic surgery and develops “cobots” (collaborative robots) for those procedures.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2006</td><td class="font-bold text-primary text-uppercase" data-order="7.8">7.8 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="energiency" tabindex="0"> <a class="text-primary" href="http://www.energiency.com/"> Energiency </a></td><td>Energiency is SaaS platform to assess and manage energy performance industrial environment.</td><td class="text-primary">Manufacturing / Logistics</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="3.3">3.3 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="energisme" tabindex="0"> <a class="text-primary" href="https://www.energisme.com/"> Energisme </a></td><td>Energisme is the software platform at the heart of energy intelligence for public, tertiary and industrial players to control their energy consumption.
Designed around the latest technologies (NoSQL, Cassandra, Elasticsearch, Cloud, Hadoop, etc.), it allows to collect and aggregate all types of multi-fluid data from heterogeneous sources. These data are then made reliable and rendered via multi-level and multi-role dashboards. Energisme provides its customers with predictive modeling tools and an ecosystem of partners to anticipate and optimize their consumption.
In 2015, the company was taken over by three entrepreneurs with complementary paths and has since grown rapidly. It has multiplied by five its workforce in less than two years. Engaged in the energy transition of the public sector, Energisme launched in early February Energisme Freemium, a free version of its Big Data platform, for local authorities and public institutions.</td><td class="text-primary">City / Infrastructures, Energy, Enterprise | Big Data and Analytics, Platforms | Big Data, Software, Sustainability, Machine Learning, Predictive Intelligence, IoT</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="6">6 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="eos innovation" tabindex="0"> <a class="text-primary" href="http://www.eos-innovation.eu/"> EOS Innovation </a></td><td>EOS Innovation conceives and designs, develops and markets e-vigilante, a mobile surveillance robot.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="event bots" tabindex="0"> <a class="text-primary" href="http://www.event-bots.fr/"> Event Bots </a></td><td>Event Bots develops robots specialized for events, including Tiki - a welcome robot.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="exensa" tabindex="0"> <a class="text-primary" href="http://www.exensa.com/"> Exensa </a></td><td>eXenSa provides Machine Learning solutions including an analytics engine.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="0.3">0.3 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="exotec solutions" tabindex="0"> <a class="text-primary" href="http://www.exotecsolutions.com/"> Exotec Solutions </a></td><td>Exotec proposes a disruptive order preparation system based on mobile robots, allowing to increase efficiency while keeping a total agility</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="4.3">4.3 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="facten" tabindex="0"> <a class="text-primary" href="https://www.facten.com/"> Facten </a></td><td>Facten is a B2B Sales application focused on Science and Technology companies, scanning and analyzing every patent, every scientific article, every tender, every public grant.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="fieldbox.ai" tabindex="0"> <a class="text-primary" href="https://www.fieldbox.ai/en/ai-for-industry/"> Fieldbox.ai </a></td><td>FieldBox.ai helps industries dramatically improve their operational efficiency thanks to artificial intelligence. The FieldBox.ai platform makes it possible to deploy AI-trained industrial bots in the heart of factories. These bots continuously and autonomously optimize processes and operate machines. By relocating decision making in factories, and automating it with AI, FieldBox.ai dramatically reduces the costs and time required to fulfill the promises of Industry 4.0.</td><td class="text-primary">Energy, Enterprise | Big Data and Analytics, Internet of Things, Oil</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="flylab" tabindex="0"> <a class="text-primary" href="http://flylab.io/"> Flylab </a></td><td>Flylab develops software and Hardware/Processing for drones and flying robots, bringing apps to drones.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="foodvisor" tabindex="0"> <a class="text-primary" href="http://www.foodvisor.io/"> Foodvisor </a></td><td>Foodvisor has developed a solution that enables to analyze a meal from a simple picture, helping people achieve a healthier lifestyle.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="fred de la compta" tabindex="0"> <a class="text-primary" href="http://www.freddelacompta.com/"> Fred de la Compta </a></td><td>Fred de la Compta develops a fully automated accounting software based on AI.</td><td class="text-primary">Enterprise | Accounting</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="geomail" tabindex="0"> <a class="text-primary" href="https://geomail.io/"> Geomail </a></td><td>Geomail reinvents custom lead generation with their geolocation algorithm.</td><td class="text-primary">Enterprise | Marketing / Sales</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="global sensing technologies" tabindex="0"> <a class="text-primary" href="http://www.gsensing.eu/"> Global Sensing Technologies </a></td><td>GST is an Artificial Intelligence (AI) hardware provider and an AI application developer</td><td class="text-primary">Hardware and Processing, Internet of Things, Platforms | Vision, Transportation, Security</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="0.075">0.075 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="gobio robot" tabindex="0"> <a class="text-primary" href="http://www.gobio-robot.com/"> Gobio robot </a></td><td>Gobio is a company specializing in robotic solutions for personal services: exoskeletons, telepresence robots...</td><td class="text-primary">Robotics, Senior Care</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="goodat" tabindex="0"> <a class="text-primary" href="https://goodat.io/"> Goodat </a></td><td>Goodat is a platform that reveals high quality potential candidates through unique profile building, artificial intelligence and data processing for HR talent screening</td><td class="text-primary">Bots | Professional, AI as a Service, Enterprise | HR and Recruiting, Platforms | Natural Language</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="gorgias" tabindex="0"> <a class="text-primary" href="https://gorgias.io/"> Gorgias </a></td><td>Gorgias is building a helpdesk which makes support agents 2x more efficient, automatically suggesting how to solve support request.</td><td class="text-primary">Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="1.6">1.6 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="goshaba" tabindex="0"> <a class="text-primary" href="http://www.goshaba.com/"> Goshaba </a></td><td>Goshaba automates candidate qualification by collecting new, reliable and comparable data. Candidates automatically get a matching score with a job. Their technology combines data, cognitive science, and video games.</td><td class="text-primary">Enterprise | Big Data and Analytics, Enterprise | HR and Recruiting, Machine Learning</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="haapie" tabindex="0"> <a class="text-primary" href="http://www.haapie.com/"> Haapie </a></td><td>Haapie designs and develops cognitive and social robots, as well as virtual characters, which integrate its advanced software components including cognitive systems, natural language speech recognition and dialogue management solutions.</td><td class="text-primary">Bots | Personal, Bots | Professional, AI as a Service, Connected home, Education, Internet of Things, Platforms | Audio, Platforms | Natural Language, Robotics, Senior Care, Software</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="haapie sas" tabindex="0"> <a class="text-primary" href="http://www.haapie.com/"> Haapie SAS </a></td><td>Haapie develops cognitive and voice assistants. The company has developped its own speech recognition, dialogue management systems and cognitive systems which can be combined and integrated in chatbots or voice assistants on any device.
These natural language text and voice interfaces facilitate information search, helping individuals at home or in the office to gain time and efficiency.</td><td class="text-primary">Bots | Platform and Tools, Bots | Professional, Connected home, Enterprise, Platforms | Natural Language, Machine Learning, Productivity and Well-being, or Personal agent</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="hease robotics" tabindex="0"> <a class="text-primary" href="http://heaserobotics.com/"> Hease Robotics </a></td><td>HEASE, the first robot tailored for retail and hospitality. HEASE informs, entertains, guides and welcomes your audience.</td><td class="text-primary">Retail, Robotics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="heek" tabindex="0"> <a class="text-primary" href="http://www.heek.com/"> Heek </a></td><td>Heek is a conversational website builder.</td><td class="text-primary">Bots | Professional, Professional Services</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="0.77">0.77 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="hellebore technologies" tabindex="0"> <a class="text-primary" href="http://www.helleboretech.com/"> Hellebore Technologies </a></td><td>Hellebore Technologies develops Machine Learning and Data Mining solutions for OTC Markets.</td><td class="text-primary">AI as a Service, Enterprise | Big Data and Analytics, Platforms | Natural Language, Platforms | Big Data, Professional Services, Science and Engineering, Software, Financial Services, Lending and investments</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="hello jam" tabindex="0"> <a class="text-primary" href="https://hellojam.fr/"> Hello JAM </a></td><td>Jam uses Artificial Intelligence and Process Optimization to help you find things to do during your free time.</td><td class="text-primary">Agents | Personal</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="1.5">1.5 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="hellotrip" tabindex="0"> <a class="text-primary" href="http://hellotrip.com/"> Hellotrip </a></td><td>Hellotrip has developed an airfare prediction technology.</td><td class="text-primary">Hospitality</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="heuritech" tabindex="0"> <a class="text-primary" href="http://www.heuritech.com/"> Heuritech </a></td><td>Heuritech enables brands to find relevant trends related to products, to improve product design and launching, by monitors blogs, images and videos to detect products in their contexts.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="1.17">1.17 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="hins" tabindex="0"> <a class="text-primary" href="http://www.claytheworld.com/"> HINS </a></td><td>HINS develops CLAY, a software solution for automated and adaptive hand recognition from simple 2D lens on smartphones. It notably adresses industrials and VR big accounts.</td><td class="text-primary">AI as a Service</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="honestica" tabindex="0"> <a class="text-primary" href="http://www.honestica.com/"> Honestica </a></td><td>Honestica provides a global platform to facilitate collaboration between physicians and enable data sharing &amp; analysis while protecting patient rights and providing maximum security.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="hoomano.com" tabindex="0"> <a class="text-primary" href="http://hoomano.com/"> Hoomano.com </a></td><td>Hoomano creates and deploys software and custom behaviors for humanoid robots, including robots from Aldebaran Nao and Pepper.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="hubware" tabindex="0"> <a class="text-primary" href="http://www.hubwa.re/"> Hubware </a></td><td>Hubware helps Customer Service Reps deal with repeating tasks and frequent questions, right from their ticketing system.</td><td class="text-primary">Bots | Professional, Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="1.5">1.5 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="hubware" tabindex="0"> <a class="text-primary" href="http://www.hubwa.re/"> Hubware </a></td><td>Hubware is building a professional assistant to disrupt customer service.</td><td class="text-primary">Bots | Professional, AI as a Service, Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="hugging face" tabindex="0"> Hugging Face</td><td>Hugging Face is building an AI which is fun to talk to everyday and that you can create a meaningful connection with.</td><td class="text-primary">Agents | Personal</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="0.3">0.3 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="hyperlex" tabindex="0"> <a class="text-primary" href="https://hyperlex.ai/"> Hyperlex </a></td><td>Hyperlex is the #1 contract management and discovery platform. It helps companies manage and make the most of their contract portfolio by extracting relevant information and data to maximize revenues opportunities, optimize expenses and mitigate risks.
Our technology rests on a combination of specifically trained natural language processing algorithms and advanced deep learning techniques.</td><td class="text-primary">Administrative Services, Legal, Software</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="1.23">1.23 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="ideta" tabindex="0"> <a class="text-primary" href="http://www.meet-ideta.com/"> Ideta </a></td><td>Ideta is a SaaS solution for Retailers and E-commerce to engage with visitors in a digital conversation and unlock prospects purchasing potential, enhancing online and in-store customer experience.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Retail</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="immersive robotics" tabindex="0"> <a class="text-primary" href="http://immersive-robotics.com/"> Immersive Robotics </a></td><td>Immersive robotics produces robots, including Waldo, a humanoid robot designed for customer service, people assistance and research.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="implicity" tabindex="0"> <a class="text-primary" href="http://www.implicity.fr/"> Implicity </a></td><td>Implicty offers a smart monitoring solution for Pacemakers and Defibrillators with AI algorithms combining device data and patients health records to determine every alert’s criticality.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="incalia" tabindex="0"> <a class="text-primary" href="http://incalia.fr/"> Incalia </a></td><td>Incalia builds custom Machine &amp; Deep Learning solutions for start ups​.</td><td class="text-primary">AI as a Service</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="innoradiant" tabindex="0"> <a class="text-primary" href="https://innoradiant.com/"> Innoradiant </a></td><td>Innoradiant leverages NLP to help companies with product development and innovation.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Sales and Marketing, Platforms | Natural Language</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="intuitive-robots.com" tabindex="0"> <a class="text-primary" href="http://intuitive-robots.com/"> Intuitive-robots.com </a></td><td>Intuitive Robots has developed a software to facilitate the usage of humanoid robots like Pepper include Ready-to-use solution &amp; applications...</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="invenis" tabindex="0"> <a class="text-primary" href="https://invenis.paris/"> Invenis </a></td><td>Invenis offers a self-service advanced Big Data / Analytics software, with no coding / analytics skills required.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="io-technology" tabindex="0"> <a class="text-primary" href="http://www.io-technology.net/"> IO-Technology </a></td><td>IO-Technology offers a smart connected home solution (home automation, energy consumption optimization, security monitoring...), with a learning and predictive analysis system.</td><td class="text-primary">Connected home</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="iqspot" tabindex="0"> <a class="text-primary" href="http://iqspot.fr/"> Iqspot </a></td><td>iQSpot is a SaaS solution to manage energy consumption for buildings, including a dashboard for monitoring consumption.</td><td class="text-primary">Connected home</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="0.3">0.3 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="isoft" tabindex="0"> <a class="text-primary" href="https://www.isoft.fr/"> ISoft </a></td><td>ISoft provides innovative High Tech solutions for data science, big data and real time fraud fighting specifically design for end user.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics, Enterprise | Security and Fraud, Platforms | Big Data, Software</td><td class="font-bold text-primary text-uppercase">1990</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="iteca" tabindex="0"> <a class="text-primary" href="http://www.iteca.eu/"> Iteca </a></td><td>ITECA is a software consulting company, which draws its expertise from Artificial Intelligence, intuitive Human Machine Interface and 3D applied to the domain of the Industry and the Future of Maintenance.</td><td class="text-primary">AI as a Service, Manufacturing / Logistics, Robotics</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="itk" tabindex="0"> <a class="text-primary" href="http://www.itk.fr/en/"> itk </a></td><td>Itk is a knowledge integrator committed to developing easy-to-use, efficient and useful decision-making tools that connect scientific research with production agriculture and allied industries to drive value to the company, its stakeholders and customers.</td><td class="text-primary">Agriculture and Farming, Predictive Intelligence, IoT</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="2">2 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="itrust" tabindex="0"> <a class="text-primary" href="http://www.itrust.fr/en"> iTrust </a></td><td>ITrust offers cybersecurity solutions and expertise including Reveelium, a behavior analysis solution, capable of detecting weak signals and anomalies.</td><td class="text-primary">Security / Fraud</td><td class="font-bold text-primary text-uppercase">2007</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="juliedesk" tabindex="0"> <a class="text-primary" href="https://www.juliedesk.com/"> JulieDesk </a></td><td>Julie Desk is a virtual assistant that uses artificial intelligence to schedule meetings and appointments of a user.</td><td class="text-primary">Agents | Professional</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="0.88">0.88 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="kalray" tabindex="0"> <a class="text-primary" href="http://www.kalrayinc.com/"> Kalray </a></td><td>KALRAY delivers the performance &amp; flexibility of manycore processors for embedded and intensive computing applications, with a technology combining a new processor architecture—called MPPA® for Multi-Purpose Processor Array—and a unique software parallel programming solution.</td><td class="text-primary">Hardware/Processing</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="kapcode" tabindex="0"> <a class="text-primary" href="http://www.kapcode.fr/"> KapCode </a></td><td>Kap-Code offers solutions in the fields of respiratory disease and health signal monitoring via social media.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="3.24">3.24 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="karos" tabindex="0"> <a class="text-primary" href="http://www.karos.fr/"> Karos </a></td><td>Karos is an innovative carpooling mobile app leveraging machine learning, big data and mobile/geolocation technologies.</td><td class="text-primary">Transportation</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="keen eye" tabindex="0"> <a class="text-primary" href="http://www.keeneye.tech/"> Keen Eye </a></td><td>Keen Eye offers a Digital Pathology Platform, specializing in image analysis solutions for contract research organisations (CROs), pathology labs and life-science research tool manufacturers.</td><td class="text-primary">Healthcare, Platforms | Vision</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="khresterion" tabindex="0"> <a class="text-primary" href="http://www.khresterion.com/"> Khresterion </a></td><td>Khresterion has developed a software focused on medical diagnostics and prescription assistance.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="lalilo" tabindex="0"> <a class="text-primary" href="http://lalilo.fr/"> Lalilo </a></td><td>Lalilo leverages AI to developed personalized education, focused first on teaching reading to kids.</td><td class="text-primary">Education</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="lamark" tabindex="0"> <a class="text-primary" href="http://lamark.io/"> Lamark </a></td><td>LAMARK is specialized in image identification solutions responding to the need of photo professionals to protect their copyright across all media.</td><td class="text-primary">Media</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="leka" tabindex="0"> <a class="text-primary" href="http://leka.io/"> Leka </a></td><td>Leka is an interactive and multi-sensory smart toy, offering children with special needs the ability to play fun and educational games that motivates social interactions, that increase motor, cognitive, and emotional skills, as well as stimulates autonomy.</td><td class="text-primary">Education</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="lexistems" tabindex="0"> <a class="text-primary" href="https://lexistems.com/"> Lexistems </a></td><td>Lexistems provides state-of-the-art Lexical and Natural Language solutions for organizations, digital services providers and text professionals.</td><td class="text-primary">Bots | Platform and Tools, Bots | Professional, AI as a Service, Enterprise, Platforms | Natural Language, Platforms | Big Data, Professional Services, Search</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="life plus" tabindex="0"> <a class="text-primary" href="https://www.lifeplus.io/"> Life Plus </a></td><td>Life Plus enables the prevention of the progressive weakening of the elderly population.</td><td class="text-primary">Healthcare, Senior Care</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="0.4">0.4 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="lighton" tabindex="0"> <a class="text-primary" href="http://lighton.io/"> LightOn </a></td><td>LightOn is a technology company developing novel optics-based computing hardware.</td><td class="text-primary">Hardware/Processing</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="lili.ai" tabindex="0"> <a class="text-primary" href="http://www.lili.ai/"> Lili.ai </a></td><td>Lili has developed a Virtual Assistant to support Project Managers (automated meeting minutes, automated task status tracking, automated documentation, automated risk scanning).</td><td class="text-primary">Agents | Professional</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="linkfluence" tabindex="0"> <a class="text-primary" href="http://linkfluence.com/"> Linkfluence </a></td><td>Linkfluence, a social media intelligence company, analyzes conversations on social networks to create business opportunities for brands.</td><td class="text-primary">Social Media</td><td class="font-bold text-primary text-uppercase">2006</td><td class="font-bold text-primary text-uppercase" data-order="24.61">24.61 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="linkurious" tabindex="0"> <a class="text-primary" href="http://linkurio.us/"> Linkurious </a></td><td>Linkurious offers graph visualization solutions, enabling its users to search, explore, and visualize graphs.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="livemon" tabindex="0"> <a class="text-primary" href="https://www.livemon.com/en-US/"> LiveMon </a></td><td>LiveMon provides an intelligent software to monitor the infrastructure &amp; applications, end-users response times, the quality of service of cloud providers and the logs.</td><td class="text-primary">AI as a Service, Enterprise | Big Data and Analytics, Software, IT Infrastructure</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="lokad" tabindex="0"> <a class="text-primary" href="https://www.lokad.com/"> Lokad </a></td><td>Lokad offers a quantitative supply chain optimization software, to help customers make better purchasing and replenishment decisions.</td><td class="text-primary">Enterprise | Big Data and Analytics, Manufacturing / Logistics</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="lore.ai" tabindex="0"> <a class="text-primary" href="http://www.lore.ai/"> Lore.ai </a></td><td>Lore has developed a cognitive computing platform capable of reading and understanding years of corporate filings, conference calls, news and social media making it easy to query, explore and interact.</td><td class="text-primary">Finance</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="lybero" tabindex="0"> <a class="text-primary" href="http://lybero.net/"> Lybero </a></td><td>Lybero.net is a startup focusing on computer security and passphrase protection softwares. It bases all its ideas on scientific and technology in the fields of cryptography and security.</td><td class="text-primary">Enterprise | Security / Fraud</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="mac lloyd" tabindex="0"> <a class="text-primary" href="http://mac-lloyd.com/"> Mac Lloyd </a></td><td>Mac-lloyd provides connected sensors to elite sports and solutions to improve performance by analyzing data.</td><td class="text-primary">Education, Sports</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="mediego" tabindex="0"> <a class="text-primary" href="http://www.mediego.com/"> Mediego </a></td><td>Mediego is a personalization solution based on a behavioral algorithm that analyzes complex data collected online or via outlets in real-time and can customize content in real time.</td><td class="text-primary">Enterprise | Marketing / Sales</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="mensiatech.com" tabindex="0"> <a class="text-primary" href="http://www.mensiatech.com/"> Mensiatech.com </a></td><td>Mensia Technologies has developed a technology enabling Real-time brain monitoring and training. They focus primarily on the issues related to attention, including pathologies such as ADHD, as well as brain aging.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="4">4 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="meteo*swift" tabindex="0"> <a class="text-primary" href="http://www.meteoswift.com/"> meteo*swift </a></td><td>meteo*swift has developed forecasting and wind farms data analytics tools, designed for wind farms operators and electricity market players.</td><td class="text-primary">City / Infrastructures</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="meteojob" tabindex="0"> <a class="text-primary" href="http://www.meteojob.com/"> Meteojob </a></td><td>Meteojob helps you find your next job. Using big data technologies, Meteojob matches your profile with job offers and proposes appropriate career evolutions</td><td class="text-primary">Enterprise | HR and Recruiting</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="3.5">3.5 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="mip robotics" tabindex="0"> <a class="text-primary" href="http://www.mip-robotics.com/"> MIP Robotics </a></td><td>MIP Robotics designs and manufactures industrial robots simple to use and affordable price thanks to technology developed in-house.</td><td class="text-primary">Manufacturing / Logistics, Robotics</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="mipsology" tabindex="0"> <a class="text-primary" href="http://www.mipsology.com/"> Mipsology </a></td><td>Mipsology's technology delivers high computation throughput for neural network and deep learning directly in data centers.</td><td class="text-primary">Hardware/Processing</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="moodstocks" tabindex="0"> <a class="text-primary" href="http://www.moodstocks.com/"> Moodstocks </a></td><td>Moodstocks provides an API and ready-to-use cross-platform SDK for developers to integrate scanning.</td><td class="text-primary">Platform | Vision</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="myscript" tabindex="0"> <a class="text-primary" href="http://myscript.com/"> MyScript </a></td><td>For more than 15 years, MyScript has earned recognition and acclaim as the core technology powering the industry’s most advanced handwriting recognition engines.</td><td class="text-primary">Education, Enterprise, Platforms | Natural Language, Science and Engineering, Software</td><td class="font-bold text-primary text-uppercase">1998</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="mytraffic" tabindex="0"> <a class="text-primary" href="http://www.mytraffic.fr/"> MyTraffic </a></td><td>MyTraffic revolutionizes commercial real estate with Big Data and Machine Learning, by helping w/ site locations for developers.</td><td class="text-primary">Real Estate and Construction, Retail</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="naio technologies" tabindex="0"> <a class="text-primary" href="http://naio-technologies.com/"> Naio Technologies </a></td><td>Naïo Technologies develops and markets robots for agriculture and viticulture.</td><td class="text-primary">Robotics, Agriculture</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="3.34">3.34 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="navya" tabindex="0"> <a class="text-primary" href="http://navya.tech/"> Navya </a></td><td>Navya has developed driverless vehicles that can move safely without any special infrastructure and without human intervention.</td><td class="text-primary">Robotics, Transportation</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="38.02">38.02 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="nehoov" tabindex="0"> <a class="text-primary" href="http://nehoov.com/en/"> Nehoov </a></td><td>Nehoov offers software solutions for data analytics and forecasting, developed for business / operational people without the need for a Data Scientist.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="neosensys" tabindex="0"> <a class="text-primary" href="http://www.neosensys.com/"> NeoSensys </a></td><td>Neosensys specializes in innovative solutions for smart video-surveillance.</td><td class="text-primary">Enterprise | Security / Fraud</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="neovision" tabindex="0"> <a class="text-primary" href="http://neovision.fr/"> Neovision </a></td><td>Neovision is a French IT R&amp;D agency, specialized in Artificial Intelligence, particularly in Computer Vision and Machine Learning.</td><td class="text-primary">AI as a Service</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="netwave" tabindex="0"> <a class="text-primary" href="http://www.netwave.eu/"> Netwave </a></td><td>Netwave offers an omnichannel personalization platform for retailers.</td><td class="text-primary">Retail</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="neuralcat" tabindex="0"> <a class="text-primary" href="http://www.neuralcat.fr/"> Neuralcat </a></td><td>NeuralCat offers AI as a service solutions.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="nexxai" tabindex="0"> <a class="text-primary" href="http://nexxai.com/"> NEXXAI </a></td><td>NEXXAI improves customer relationships with its artificial intelligence solution for processing incoming emails (automatic categorization, feeling analysis, automatic response suggestion) and churn predicitive solution.</td><td class="text-primary">AI as a Service, Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics, Insurance, Financial Services, Lending and investments</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="niland" tabindex="0"> <a class="text-primary" href="http://niland.io/"> Niland </a></td><td>Niland is a music technology company that provides music search &amp; discovery engines based on Deep Learning &amp; Machine Listening algorithms.</td><td class="text-primary">Platform | Audio</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="occi.io" tabindex="0"> <a class="text-primary" href="http://www.occi.io/"> Occi.io </a></td><td>Occi has developed shopping cart tracking solutions in physical stores, enabling retailers to understand and interact with every consumer in real time inside a large retail store.</td><td class="text-primary">Retail</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="octopus robots (mcai sas)" tabindex="0"> <a class="text-primary" href="http://www.octopusrobots.com/"> Octopus Robots (MCAI SAS) </a></td><td>Octopus Robotics develops mobile, intelligent and autonomous robots intended for professionals, especially those involved in: Agro-food, animal healthcare, Biotech, Security &amp; Defence.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2004</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="opla" tabindex="0"> <a class="text-primary" href="https://opla.ai/"> Opla </a></td><td>Opla is a unique and agnostic software platform that allows companies to build and deploy unique Conversational Robots in their ecosystem.
Coded from scratch, from builder to NLP, to be independent from any external programs and provide maximum data security. Messaging platforms and AI agnostic. Deployed around a solid home-made open-source core.
Designed for non-coder users, to bring autonomy and agility to company experts.</td><td class="text-primary">Bots | Platform and Tools, Bots | Professional, AI as a Service, Agents | Platform / Tools</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="1">1 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="orelia" tabindex="0"> <a class="text-primary" href="http://www.orelia.fr/"> Orelia </a></td><td>ORELIA develops solutions (software + hardware) for audio analysis and detection, including solutions enabling industrials to integrate ad-hoc audio analysis in their products.</td><td class="text-primary">City / Infrastructures, Enterprise, Government and Military, Internet of Things, Manufacturing / Logistics, Software</td><td class="font-bold text-primary text-uppercase">2007</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="otosense" tabindex="0"> <a class="text-primary" href="http://otosense.com/"> Otosense </a></td><td>OtoSense is an infrastructure software company, offering sound recognition platform for enterprises to build value through sound intelligence.</td><td class="text-primary">Platform | Audio</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="1.2">1.2 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="ottspott" tabindex="0"> <a class="text-primary" href="http://ottspott.co/"> Ottspott </a></td><td>Ottspott integrates with your Slack channel and creates a local phone number that can be used with clients for both in and outbound calls.</td><td class="text-primary">Enterprise</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="owi" tabindex="0"> <a class="text-primary" href="http://owi-tech.com/fr/accueil/"> OWI </a></td><td>Artificial intelligence to understand the natural language of your customer and to automate tasks in your customer service with no added value.</td><td class="text-primary">Bots | Professional, Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="owkin" tabindex="0"> <a class="text-primary" href="http://www.owkin.com/"> Owkin </a></td><td>OWKIN builds algorithms that can interpret omics, visual data, biostatistics and patient profiles, to accelerate drug discovery and precision medicine.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="ownpage technology" tabindex="0"> <a class="text-primary" href="http://www.ownpage.fr/"> Ownpage Technology </a></td><td>Ownpage Technology offers personalization solutions for publishers.</td><td class="text-primary">Media</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="oyst" tabindex="0"> <a class="text-primary" href="http://www.oyst.com/"> Oyst </a></td><td>Oyst wants to make e-merchant and e-shopper's life easier by enabling users to buy in 1-click all over the web</td><td class="text-primary">Advertising and AdTech, Enterprise | Sales and Marketing, Enterprise | Security and Fraud, E-Commerce, Payment</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase" data-order="3">3 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="o² quant" tabindex="0"> <a class="text-primary" href="http://www.o2quant.com/"> O² Quant </a></td><td>O²Quant is a software developer / consulting company specializing in deep learning</td><td class="text-primary">AI as a Service</td><td class="font-bold text-primary text-uppercase">2017</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="partnering robotics" tabindex="0"> <a class="text-primary" href="https://partnering-robotics.com/"> Partnering Robotics </a></td><td>Partnering Robotics develops robotics solution for public paces from security robots to air purifier ones.</td><td class="text-primary">Robotics, Service care</td><td class="font-bold text-primary text-uppercase">2007</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="pixmap" tabindex="0"> <a class="text-primary" href="http://www.pixmap3d.com/"> Pixmap </a></td><td>PIXMAP provides robots with the ability to represent the world around them in 3D, in a photo-realistic manner, and allows them to localize themselves, whatever their shape, size or mode of locomotion.</td><td class="text-primary">Robotics, Platform | Vision</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="pixyl" tabindex="0"> <a class="text-primary" href="http://pixylmedical.com/"> Pixyl </a></td><td>Pixyl empowers clinicians with faster access to precise, clinically relevant data, by delivering precise neuroimaging biomarker extraction for improved insight and decision-making in clinical studies and routine clinical practice.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="planorama" tabindex="0"> <a class="text-primary" href="http://www.planorama.com/"> Planorama </a></td><td>Planorama helps CPG companies digitalize in-store measurements: with their Image Recognition solutions for Retail, they offer real-time actionable insights from a simple shelf photo.</td><td class="text-primary">Retail</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="8.1">8.1 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="plume labs" tabindex="0"> <a class="text-primary" href="http://plumelabs.com/"> Plume Labs </a></td><td>Plume Labs offers a solution to monitor air pollution to prevent its impact on health with their air quality forecasting app, AI for personalized recommendations, and hardware for personal pollution sensing.</td><td class="text-primary">City / Infrastructures</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="pmcompanion" tabindex="0"> <a class="text-primary" href="http://www.pmcompanion.fr/"> PMCompanion </a></td><td>PMCompanion is a consulting company leveraging AI to learn, analyze, anticipate and secure projects.</td><td class="text-primary">Bots | Professional, AI as a Service, Enterprise, Enterprise | Business and Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="pocketconfidant ai" tabindex="0"> <a class="text-primary" href="http://pocketconfidant.com/"> PocketConfidant AI </a></td><td>PocketConfidant is the first confidant available 24/7, facilitating conversations to develop awareness, reflection and learning opportunities. It is reinventing self-help coaching.</td><td class="text-primary">Bots | Personal, Bots | Professional, AI as a Service, Education, Enterprise</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="0.350">0.350 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="pollen robotics" tabindex="0"> <a class="text-primary" href="http://pollen-robotics.com/en/"> Pollen robotics </a></td><td>Pollen Robotics creates open technologies to enable DIY robotics.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="predictice" tabindex="0"> <a class="text-primary" href="https://predictice.com/"> Predictice </a></td><td>Predictice offers a platform delivering smart analytics to support the law professional in the case law analysis process and in the trends and phenomena identification.</td><td class="text-primary">Enterprise | Big Data and Analytics, Legal, Platforms | Big Data</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="prevision.io" tabindex="0"> <a class="text-primary" href="https://www.prevision.io/"> Prevision.io </a></td><td>Prevision.io is a Machine Learning cloud platform, oriented towards usage and providing results as a service. It is IoT compliant for M2M AI.</td><td class="text-primary">Machine Learning, Predictive Intelligence, IoT</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="pricematch" tabindex="0"> <a class="text-primary" href="https://www.pricematch.travel/en/"> Pricematch </a></td><td>PriceMatch is a personalized revenue management company focused on individualizing revenue management for hotels.</td><td class="text-primary">Hospitality</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="10.38">10.38 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="prizm" tabindex="0"> <a class="text-primary" href="http://meetprizm.com/"> Prizm </a></td><td>Prizm is a device that converts speakers into learning music players adjusting the music to the people in a room, their music tastes and habits, and current atmosphere.</td><td class="text-primary">Media</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="probayes" tabindex="0"> <a class="text-primary" href="http://www.probayes.com/en/"> ProbaYes </a></td><td>ProbaYes, a team of machine learning and optimization experts, offering Data Science services and solutions to its clients.</td><td class="text-primary">AI as a Service, Energy</td><td class="font-bold text-primary text-uppercase">2003</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="prophesee" tabindex="0"> <a class="text-primary" href="http://www.prophesee.ai/"> Prophesee </a></td><td>Chronocam develops innovative computer vision sensors and systems for applications in all fields of artificial vision. The sensor technology is inspired by biological eyes, acquiring and processing the visual information in an extremely performing yet highly efficient way.</td><td class="text-primary">Platform | Vision, Hardware/Processing</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="37.3">37.3 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="proxem" tabindex="0"> <a class="text-primary" href="http://www.proxem.com/"> Proxem </a></td><td>Proxem has developed NLP solutions from e-reputation to consumer feedback analysis....</td><td class="text-primary">Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2007</td><td class="font-bold text-primary text-uppercase" data-order="1.18">1.18 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="qopius" tabindex="0"> <a class="text-primary" href="http://www.qopius.com/"> Qopius </a></td><td>Qopius enables companies/individuals to build and train their own artificially intelligent modules withing their existing applications easily, with a suite of vertically developed AI products (Retail, Finance...).</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="quantmetry" tabindex="0"> <a class="text-primary" href="http://www.quantmetry.com/"> Quantmetry </a></td><td>Quantmetry offers solutions to manage Data Science and Big Data across various business functions such as Marketing, Sales, Finance.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence, Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="qucit" tabindex="0"> <a class="text-primary" href="http://qucit.com/"> Qucit </a></td><td>Qucit provides APIs, standalone application and consulting services to implement optimal strategies for planning and operating transport infrastructure inc. bike sharing and parking.</td><td class="text-primary">City / Infrastructures</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="quicksign" tabindex="0"> <a class="text-primary" href="https://www.quicksign.com/fr/"> QuickSign </a></td><td>QuickSign is an end-to-end Digital Contract Management solution to sign and handle contracts with electronic signatures. To achieve straight-through processing, QuickSign replaces the printer, scanner and couriers traditionally used in contract signing with digital workflows integrating AI to automate document analysis.</td><td class="text-primary">Administrative Services, Digital Contract Management</td><td class="font-bold text-primary text-uppercase">2006</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="quinten" tabindex="0"> <a class="text-primary" href="http://www.quinten-france.com/"> Quinten </a></td><td>As a pioneer in the field of Data Science, Quinten offers consulting services and advanced decision support solutions that truly delivers value in a large number of sectors and applications (healthcare, insurance, banking, media, aerospace, automotive).</td><td class="text-primary">Enterprise | Business + Predictive Intelligence, Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="qynapse" tabindex="0"> <a class="text-primary" href="http://www.qynapse.com/"> Qynapse </a></td><td>Qynapse provides innovative technology to measure drug efficacy and predict disease outcome in neurology.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="rb3d" tabindex="0"> <a class="text-primary" href="http://www.rb3d.com/en/"> RB3D </a></td><td>RB3D develops exoskeletons and cobots.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2001</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="recast.ai" tabindex="0"> <a class="text-primary" href="http://recast.ai/"> Recast.AI </a></td><td>Recast.ai has developed a platform enabling companies to build their own conversational bot.</td><td class="text-primary">Agents | Platform / Tools</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="1.12">1.12 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="recommerce solutions" tabindex="0"> <a class="text-primary" href="http://www.recommerce-solutions.com/"> Recommerce Solutions </a></td><td>Recommerce Solutions develops a dedicated platform for remanufacturing of second hand electronics, leveraging predictive AI for pricing and product matching.</td><td class="text-primary">Insurance, Manufacturing / Logistics, Platforms | Big Data, Sustainability</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="10">10 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="regaind" tabindex="0"> <a class="text-primary" href="http://regaind.io/"> Regaind </a></td><td>Regaind has developed a solution to enable a better photo search and album creation.</td><td class="text-primary">Platform | Vision</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="reminiz" tabindex="0"> <a class="text-primary" href="http://www.reminiz.com/"> Reminiz </a></td><td>Reminiz is a face recognition app that enables its users to identify celebrities, scanning celebrity images and displaying contextual information on Smartphones, Smart TV, Set-top-box, and tablets.</td><td class="text-primary">Platform | Vision, Media</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="rhythm" tabindex="0"> <a class="text-primary" href="http://rythm.co/"> Rhythm </a></td><td>Rythm builds consumer technology that stimulates the brain to enhance human potential. Our product, Dreem, is the first active wearable device to increase sleep quality.</td><td class="text-primary">Healthcare, Productivity</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="riminder" tabindex="0"> <a class="text-primary" href="http://riminder.net/"> Riminder </a></td><td>Riminder leverages AI to improve recruiting decisions as well as career path recommendations.</td><td class="text-primary">Enterprise | HR / Recruiting</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="robocare lab" tabindex="0"> <a class="text-primary" href="http://www.robocarelab.com/"> RoboCare Lab </a></td><td>Robocare develops telepresence robots and PRESENCE+, a full range of innovative services based on connected devices and robots for elderly care.</td><td class="text-primary">Robotics, Senior Care</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="robocortex" tabindex="0"> <a class="text-primary" href="http://www.robocortex.com/"> Robocortex </a></td><td>ROBOCORTEX develops Computer vision solutions from Augmented Reality to Autonomous robotics.</td><td class="text-primary">Robotics, Platform | Vision</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="robosoft services robots" tabindex="0"> <a class="text-primary" href="http://www.robosoft.com/"> Robosoft Services Robots </a></td><td>Robosoft focuses its development on infrastructure-free autonomous vehicles for goods transportation and industrial solutions.</td><td class="text-primary">Robotics, Service care</td><td class="font-bold text-primary text-uppercase">1985</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="récital" tabindex="0"> <a class="text-primary" href="https://recital.ai/"> Récital </a></td><td>Récital - focused on NLP - sells different products based on its research incl. Quieto, an automatic email processing assistant and Genius, a Q&amp;A system working on any amount of textual data.</td><td class="text-primary">Bots | Professional, Enterprise, Enterprise | Customer Support, Enterprise | Sales and Marketing, Financial Services, Lending and investments, Insurance, Legal, Search, Finance</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="saagie" tabindex="0"> <a class="text-primary" href="http://www.saagie.com/"> Saagie </a></td><td>Saagie is a smart data platform, enabling real time insights, correlations between internal and external data sources and predictive algorithms.</td><td class="text-primary">Enterprise | Big Data and Analytics</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="12.51">12.51 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="salezeo" tabindex="0"> <a class="text-primary" href="http://www.salezeo.com/"> Salezeo </a></td><td>Salezeo offers a Lead Generation solution, combining Europe's biggest B2B collaborative database with a unique technology to identify website visitors.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Sales and Marketing</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="2.05">2.05 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="scortex.io" tabindex="0"> <a class="text-primary" href="http://scortex.io/"> Scortex.io </a></td><td>Scortex.io mission is to bring vision intelligence to machines, robots, and devices, from quality control to robot vision.</td><td class="text-primary">Platform | Vision, Hardware/Processing</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="semdee" tabindex="0"> <a class="text-primary" href="http://www.semdee.com/"> Semdee </a></td><td>Semdee offers a comprehensive suite of text mining and unstructured data analytics solutions with its API.</td><td class="text-primary">Enterprise | Big Data and Analytics, Platforms | Natural Language</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="semiocast" tabindex="0"> <a class="text-primary" href="https://semiocast.com/"> Semiocast </a></td><td>Founded by Ph.D. in AI, Semiocast leverages multiple artificial intelligence technologies to provide market and opinion research solutions based on social media conversations</td><td class="text-primary">Bots | Professional, Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics, Enterprise | Sales and Marketing, Social Media</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="sende.rs" tabindex="0"> <a class="text-primary" href="https://sende.rs/"> Sende.rs </a></td><td>Senders is a contextual intelligence email service enhancing the email by helping users filter the messaging signal from the noise and providing relevant information in a device / email provider agnostic way.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence, Productivity</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="sepage" tabindex="0"> <a class="text-primary" href="http://www.sepage.com/"> Sepage </a></td><td>Sépage’s unique and innovative approach is based on an intelligent information treatment permitted by Semantic Web technologies.</td><td class="text-primary">Platform | Natural Language</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="0.8">0.8 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="sesamm" tabindex="0"> <a class="text-primary" href="http://sesamm.com/"> SESAMm </a></td><td>SESAMm develops stock market forecasting tools based on social media and other textual data sources for banks and hedge funds.</td><td class="text-primary">AI as a Service, Enterprise | Big Data and Analytics, Financial Services, Lending and investments, Asset Management</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="1.06">1.06 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="shift technology" tabindex="0"> <a class="text-primary" href="http://www.shift-technology.com/"> Shift Technology </a></td><td>Shift Technology leverages the best of data science to automatically detect networks of fraudsters in insurance and e-commerce. The solution is integrated to our cutting edge Big Data platform, and is provided in a SaaS model.</td><td class="text-primary">Insurance, Enterprise | Security / Fraud</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="39.8">39.8 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="sicara" tabindex="0"> <a class="text-primary" href="http://www.sicara.com/"> Sicara </a></td><td>Sicara builds tailor-made solutions in Big Data, computer vision, and NLP for amazing clients.</td><td class="text-primary">AI as a Service, Professional Services</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="sidetrade" tabindex="0"> <a class="text-primary" href="http://fr.sidetrade.com/"> Sidetrade </a></td><td>Sidetrade develops customer engagement software suite incl. predictive marketing and sales acceleration.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2000</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="simsoft 3d" tabindex="0"> <a class="text-primary" href="http://www.simsoft3d.fr/"> SimSoft 3D </a></td><td>SimSoft3D built an innovative voice guiding application led by an intelligent virtual assistant / supervisor to, on one hand, assist the field worker in most of their tasks.</td><td class="text-primary">Bots | Professional, Energy, Enterprise, Enterprise | Customer Support, Manufacturing / Logistics, Platforms | Audio, Platforms | Natural Language, Robotics, Software, Pharmacy, Therapies and Drugs</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="sinequa" tabindex="0"> <a class="text-primary" href="http://www.sinequa.com/"> Sinequa </a></td><td>Sinequa offers a "Cognitive Insight Platform": a real-time Big Data Search &amp; Analytics platform for Fortune Global 2000 companies with a Unified Information Access to all textual and database data, supported by analytics.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2002</td><td class="font-bold text-primary text-uppercase" data-order="5.33">5.33 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="skillcorner" tabindex="0"> <a class="text-primary" href="http://www.skillcorner.fr/"> SkillCorner </a></td><td>SkillCorner offers a dynamic analysis of performance and an innovative and interactive visualization for professional team sports including for live sport events.</td><td class="text-primary">Education, Sports</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="smart me up" tabindex="0"> <a class="text-primary" href="http://www.smartmeup.org/"> Smart Me Up </a></td><td>Smart Me Up provides an Embedded Computer vision technology (Face recognition, Object identification)</td><td class="text-primary">Platform | Vision</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="2.2">2.2 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="smarter time" tabindex="0"> <a class="text-primary" href="http://www.smartertime.com/"> Smarter Time </a></td><td>Smarter Time leverages AI to help people better understand and manage their time.</td><td class="text-primary">Productivity and Well-being, or Personal agent</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="0.2">0.2 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="smartly.ai" tabindex="0"> <a class="text-primary" href="https://smartly.ai/"> Smartly.ai </a></td><td>Smartly.ai is a all in one platform for your voice and chat bots projects.</td><td class="text-primary">Agents | Platform / Tools</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="0.45">0.45 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="smartprospective.com" tabindex="0"> <a class="text-primary" href="http://www.smartprospective.com/"> Smartprospective.com </a></td><td>Smart Prospective offers a solution enabling a real-time customization of in-store signages based on nearby lead / customers data collected.</td><td class="text-primary">Retail</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="snapdata" tabindex="0"> <a class="text-primary" href="http://www.snap-data.mobi/"> Snapdata </a></td><td>Snapdata develops a smart sales assistant for sales. Update your CRM via voice instructions.</td><td class="text-primary">Bots | Professional</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="snips.ai" tabindex="0"> <a class="text-primary" href="http://snips.ai/"> Snips.ai </a></td><td>Snips has developed an on-device AI assistant SDK.</td><td class="text-primary">Agents | Platform / Tools</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="21">21 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="softlaw" tabindex="0"> <a class="text-primary" href="http://www.softlaw.digital/"> SoftLaw </a></td><td>SoftLaw develops a software which relies on artificial intelligence to facilitate the review and analysis of legal / contractual documents and the processing of the data contained therein.</td><td class="text-primary">Administrative Services, Legal, Software</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="sophia genetics" tabindex="0"> <a class="text-primary" href="http://www.sophiagenetics.com/"> Sophia Genetics </a></td><td>Sophia Genetics developed SOPHiA, a collective artificial intelligence for clinical genomics, helping healthcare professionals better diagnose and treat patients.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="28.75">28.75 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="spirops" tabindex="0"> <a class="text-primary" href="http://www.spirops.com/"> SpirOps </a></td><td>SpirOps is a R&amp;D Lab focused on Artificial Intelligence issues. Decision Making, Procedural Animation, Dialog, Planning</td><td class="text-primary">AI as a Service, Gaming, Internet of Things, Robotics, Science and Engineering, Software, Transportation, Procedural Animation</td><td class="font-bold text-primary text-uppercase">2004</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="squadrone system / hexo+" tabindex="0"> <a class="text-primary" href="http://www.hexoplus.com/"> Squadrone System / HEXO+ </a></td><td>Squadrone System, the company behind HEXO+, an Autonomous FlyingCam.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="3">3 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="stanley robotics" tabindex="0"> <a class="text-primary" href="http://wwww.stanley-robotics.com/"> Stanley Robotics </a></td><td>Stanley Robotics aims to develop a robotic valet parking service, available to all types of personal car.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="still human" tabindex="0"> <a class="text-primary" href="http://www.cyborg-vegetal.fr/"> Still Human </a></td><td>Still Human is a robotic start up working on a Vegetal Cyborg toimprove vegetal with robotics and create a new species of autonomous and smart plant.</td><td class="text-primary">Robotics</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="stimul activ" tabindex="0"> <a class="text-primary" href="http://stibox.eu/"> Stimul Activ </a></td><td>Stimul’Activ develops cognitive stimulation tools for the patients suffering from dementia and neuro degenerative diseases.</td><td class="text-primary">Robotics, Service care</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="syllabs" tabindex="0"> <a class="text-primary" href="http://www.syllabs.com/"> Syllabs </a></td><td>Syllabs has developed robot writers to produce human-quality stories from data, information processing solutions to detect, gather, tag and link news or documents.</td><td class="text-primary">Media</td><td class="font-bold text-primary text-uppercase">2006</td><td class="font-bold text-primary text-uppercase" data-order="2.46">2.46 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="synapse developpement" tabindex="0"> <a class="text-primary" href="http://www.synapse-developpement.fr/"> Synapse Developpement </a></td><td>Synapse develops NLP solutions, focused on increasing the attractiveness of their customer’s technical solutions (Synapse Semantic Solutions) and Customer service (chatbot, dynamic FAQ).</td><td class="text-primary">Bots | Professional, AI as a Service, Content and Publishing, Enterprise | Big Data and Analytics, Platforms | Big Data, Professional Services, Search</td><td class="font-bold text-primary text-uppercase">1994</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="tac economics" tabindex="0"> <a class="text-primary" href="http://www.taceconomics.com/"> Tac Economics </a></td><td>Tac Economics is an Economics Research group leveraging NLP and datamining techniques.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Big Data and Analytics, Economic and Financial Analyses for Multinational Companies, Banks and Asset Managers</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="talentoday" tabindex="0"> <a class="text-primary" href="https://www.talentoday.com/"> Talentoday </a></td><td>Talentoday, a People Analytics solution, provides individuals and enterprises with intelligent recommendations for career success.</td><td class="text-primary">Enterprise | HR and Recruiting</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="4.94">4.94 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="tastehit" tabindex="0"> <a class="text-primary" href="https://tastehit.com/"> Tastehit </a></td><td>Tastehit has developed a Virtual salesperson solution for online shops with personalized product recommendations.</td><td class="text-primary">Retail, Enterprise | Marketing / Sales</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="teklia" tabindex="0"> <a class="text-primary" href="http://www.teklia.com/"> Teklia </a></td><td>Teklia offers AI consulting services based on a network of scientific experts.</td><td class="text-primary">AI as a Service, Enterprise | Big Data and Analytics</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="tellmeplus" tabindex="0"> <a class="text-primary" href="http://www.tellmeplus.com/"> Tellmeplus </a></td><td>TellMePlus is an innovative platform linking in a relevant way advertisers and qualified users using a predictive profiling engine, non-intrusively and respecting the user's privacy.</td><td class="text-primary">AdTech</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="4.7">4.7 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="therapixel" tabindex="0"> <a class="text-primary" href="http://therapixel.com/"> Therapixel </a></td><td>Therapixel aims at transforming diagnostic radiology with artificial intelligence.</td><td class="text-primary">Healthcare</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="1">1 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="tilkee" tabindex="0"> <a class="text-primary" href="http://www.tilkee.com/"> Tilkee </a></td><td>Tilkee is a cloud based app that increases sales team's closing rate and optimizes prospects follow-up by tracking business proposals.</td><td class="text-primary">Enterprise | Marketing / Sales</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase" data-order="0.7">0.7 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="tinyclues" tabindex="0"> <a class="text-primary" href="http://www.tinyclues.com/"> Tinyclues </a></td><td>Tinyclues enables marketers to generate more revenue from their customer database and CRM by reaching the right audience on any campaign, based on its unique AI-powered targeting solution.</td><td class="text-primary">Enterprise | Marketing / Sales</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase" data-order="25.4">25.4 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="tivine" tabindex="0"> <a class="text-primary" href="http://www.tivine.com/"> Tivine </a></td><td>TiVine Technologies, specialized in second screen applications, develops TiVipedia to answer all questions when watching any TV program.</td><td class="text-primary">Media</td><td class="font-bold text-primary text-uppercase">2013</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="traaser" tabindex="0"> <a class="text-primary" href="http://www.traaser.com/"> Traaser </a></td><td>Traaser, specialist of health data analysis has developped Diagen, medical-grade AI Technology to speed genomic analysis for personalized healthcare of cancer, genetic and complex diseases.
Traaser is a spin-off of the CEA located at Genopole and laureate of the "Concours mondial de l’innovation"</td><td class="text-primary">AI as a Service</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="1">1 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="twinswheel" tabindex="0"> <a class="text-primary" href="http://www.twinswheel.fr/"> TwinswHeel </a></td><td>Twinswheel is developing an autonomous parcel delivery droid for the future of last mile urban delivery</td><td class="text-primary">Manufacturing / Logistics</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="ubiant" tabindex="0"> <a class="text-primary" href="http://www.ubiant.com/"> Ubiant </a></td><td>Ubiant has developed Hemis (Home Energy Management Intelligent System), a smart solution for superior energy efficiency.</td><td class="text-primary">Connected home</td><td class="font-bold text-primary text-uppercase">2011</td><td class="font-bold text-primary text-uppercase" data-order="7">7 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="uchidata" tabindex="0"> <a class="text-primary" href="http://uchidata.com/"> Uchidata </a></td><td>Uchidata is a Text-Mining API which makes it easy to analyze, classify and tag texts in real time.</td><td class="text-primary">Platform | Natural Language</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="vade secure" tabindex="0"> <a class="text-primary" href="http://www.vadesecure.com/"> Vade Secure </a></td><td>Vade Secure is an email security provider, serving400M mailboxes through Internet Service Providers, hosting companies, OEM Agreement with companies like Cisco, Microsoft and also enterprises.</td><td class="text-primary">Science and Engineering, Security</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="15">15 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="vekia" tabindex="0"> <a class="text-primary" href="http://www.vekia.fr/"> Vekia </a></td><td>Vekia developed predictive planning software that uses the latest advances in research to model the complex problems of supply chains.</td><td class="text-primary">Manufacturing / Logistics</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase" data-order="17.03">17.03 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="verteego" tabindex="0"> <a class="text-primary" href="http://www.verteego.com/"> Verteego </a></td><td>Verteego designs and provides smart data management solutions combining prescriptive analytics with Business, Economic, Environment, Social, Governance information expertise.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="viavoo" tabindex="0"> <a class="text-primary" href="http://viavoo.com/"> viavoo </a></td><td>Viavoo provides sentiment and text analytics software for customer feedback.</td><td class="text-primary">Enterprise | Customer Support</td><td class="font-bold text-primary text-uppercase">2009</td><td class="font-bold text-primary text-uppercase" data-order="2">2 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="visualbot.ai" tabindex="0"> <a class="text-primary" href="http://visualbot.ai/"> Visualbot.ai </a></td><td>Visualbot is an AI enabled customer experience solution tailored for retailers (AI powered customer assistant) that includes 30 packaged, tested and trained conversational scenarios that are constantly improved.</td><td class="text-primary">Bots | Platform and Tools</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="2">2 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="vivoka" tabindex="0"> <a class="text-primary" href="http://www.vivoka.com/"> Vivoka </a></td><td>Vivoka develops a smart home solution w/ a digital butler.</td><td class="text-primary">Connected home, Robotics</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="voxist" tabindex="0"> <a class="text-primary" href="http://www.voxist.com/"> Voxist </a></td><td>Thanks to the latest innovations in AI, Voxist will transform your voicemail into a vocal assistant</td><td class="text-primary">Bots | Personal, Bots | Professional, Messaging and Telecommunications, Platforms | Audio, Software</td><td class="font-bold text-primary text-uppercase">2016</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="vulog" tabindex="0"> <a class="text-primary" href="http://www.vulog.com/"> Vulog </a></td><td>Vulog is a leader in the new generation of carsharing technology ( Free-Floating / One-Way), with its end-to-end solutions enabling mobility operators to launch large-scale carsharing services.</td><td class="text-primary">Transportation</td><td class="font-bold text-primary text-uppercase">2006</td><td class="font-bold text-primary text-uppercase" data-order="31.06">31.06 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="wall-ye" tabindex="0"> <a class="text-primary" href="http://wall-ye.com/"> Wall-Ye </a></td><td>Wall-Ye develops farming robots.</td><td class="text-primary">Robotics, Agriculture</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="walnut algorithms" tabindex="0"> <a class="text-primary" href="http://www.walnutalgorithms.com/"> Walnut Algorithms </a></td><td>Walnut Algorithms is an award-winning tech startup applying machine learning &amp; data science to investment management.</td><td class="text-primary">Financial Services, Lending and investments</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase" data-order="0.8">0.8 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="wandercratft" tabindex="0"> <a class="text-primary" href="http://www.wandercraft.eu/"> Wandercratft </a></td><td>Wandercraft has developped the first medical exoskeleton daily usable with dynamic and stable walk without crutches for paralysed people.</td><td class="text-primary">Healthcare, Robotics</td><td class="font-bold text-primary text-uppercase">2012</td><td class="font-bold text-primary text-uppercase" data-order="4.44">4.44 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="we transit labs" tabindex="0"> <a class="text-primary" href="http://wetransit.co/wp/"> We Transit Labs </a></td><td>We Transit Labs analyzes and predicts disruptions in public transportation.</td><td class="text-primary">City / Infrastructures, Transportation</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="ween" tabindex="0"> <a class="text-primary" href="https://www.ween.fr/"> Ween </a></td><td>Ween has developed a smart thermostat at the hear of the connected home.</td><td class="text-primary">Energy</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase" data-order="2">2 M$</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="wiidii" tabindex="0"> <a class="text-primary" href="http://www.wiidii.com/"> Wiidii </a></td><td>Wiidii is a hybrid personal assistant combining both human intelligence with real personal assistants and artificial intelligence.</td><td class="text-primary">Agents | Personal</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="wyca robotics" tabindex="0"> <a class="text-primary" href="http://www.wyca-robotics.com/"> Wyca Robotics </a></td><td>Wyca develops Keylo, a robotic solution helping retailers or facilities managers to receive and serve clients and visitors remotely.</td><td class="text-primary">Retail, Robotics</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="xbrain" tabindex="0"> <a class="text-primary" href="http://xbrain.io/"> xBrain </a></td><td>xBrain has developed a very powerful NLP technology to build AI assistants for the connected things with a focus on cars.</td><td class="text-primary">Agents | Platform / Tools</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="xtrem logic" tabindex="0"> <a class="text-primary" href="http://www.xtremlogic.com/"> Xtrem Logic </a></td><td>XtremLogic delivers next generation green high-performance computing on FPGAs with up to 100 times better performance/cost ratio than existing solutions.</td><td class="text-primary">Hardware</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="ysance" tabindex="0"> <a class="text-primary" href="http://www.ysance.com/"> Ysance </a></td><td>Ysance enables marketing teams to recognize and qualify their anonymous digital audience and engage them in personalized interactions, across all channels with their DMP solutions.</td><td class="text-primary">Enterprise | Business and Predictive Intelligence, Enterprise | Sales and Marketing</td><td class="font-bold text-primary text-uppercase">2005</td><td class="font-bold text-primary text-uppercase" data-order="5.6">5.6 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="yseop" tabindex="0"> <a class="text-primary" href="http://yseop.com/"> Yseop </a></td><td>Yseop offers Natural Language Generation solutions: transforming data into reports and expertise, in multiple languages &amp; in real time.</td><td class="text-primary">Platform | Natural Language</td><td class="font-bold text-primary text-uppercase">2008</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="yumii" tabindex="0"> <a class="text-primary" href="http://www.yumii.io/"> Yumii </a></td><td>Yumii is an interaction platform between elder at home and their family, helpers, charities and doctors.</td><td class="text-primary">Healthcare, Senior Care</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="zelros" tabindex="0"> <a class="text-primary" href="http://www.zelros.com/"> Zelros </a></td><td>Zelros is a collaborative platform allowing organizations to quickly create useful machine learning applications.</td><td class="text-primary">Enterprise | Business + Predictive Intelligence</td><td class="font-bold text-primary text-uppercase">2015</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="zenly" tabindex="0"> <a class="text-primary" href="https://zen.ly/"> Zenly </a></td><td>Zenly develops frictionless location sharing.</td><td class="text-primary">Messaging and Telecommunications, Social Media</td><td class="font-bold text-primary text-uppercase">2010</td><td class="font-bold text-primary text-uppercase" data-order="25">25 M$</td></tr><tr role="row" class="even"><td class="font-bold text-uppercase sorting_1" data-order="zettafox.com" tabindex="0"> <a class="text-primary" href="http://www.zettafox.com/"> Zettafox.com </a></td><td>Zettafox provides services and customized solutions in Advanced Analytics and Data Science.</td><td class="text-primary">Big Data / Machine Learning</td><td class="font-bold text-primary text-uppercase">2014</td><td class="font-bold text-primary text-uppercase">N/C</td></tr><tr role="row" class="odd"><td class="font-bold text-uppercase sorting_1" data-order="zyl" tabindex="0"> <a class="text-primary" href="https://zyl.ai/"> Zyl </a></td><td>Zyl seeks to change how people experience and remember the valuable moments in life.
Zyl is the first AI-powered photo app that relives your best photos and helps you re-engage with your friends.</td><td class="text-primary">Consumer app, Machine Learning</td><td class="font-bold text-primary text-uppercase">N/C</td><td class="font-bold text-primary text-uppercase" data-order="0.15">0.15 M$</td></tr></tbody></table></div></div></div></div></section><section><div class="cta bg-cover bg-fixed pos-rlt has-bg" style="background-color: #062048;"> <img class="pos-abt h-full bg-left" src="./France-is-AI_files/bg-particules-2-reverse-1.png" alt=""><img class="pos-abt h-full bg-right" src="./France-is-AI_files/bg-particules-2-1.png" alt=""><div class="_pit-section  normal"><div class="section-menu-padding"></div><div class="section-introduction"><div class="container"><h1>We are an initiative powered by volunteers, join us to support the ecosystem</h1> <a target="" href="https://franceisai.com/get-involved" class="btn plain white primary">Get involved<i class="fa fa-long-arrow-right m-l-6"></i></a></div></div></div></div></section><footer class="section-footer"><div class="section-personal-info p-y-10"><div class="container d-flex w-full flex-column flex-sm-row justify-content-center"><div class="col-12 col-sm-6 col-md-3 text-center"> <img src="./France-is-AI_files/photo-portrait.png" alt=""></div><div class="col-12 col-sm-6 col-md-3"><div class="personal-name"><h2>Damien Gromier</h2></div><div class="personal-role"><p class="p1"><span style="color: #0d64eb; text-transform: uppercase;"><b>Président @ France Is Ai</b></span></p> <a target="_blank" href="https://www.linkedin.com/in/damien-gromier-862a0426/"><i class="fa fa-linkedin-square"></i></a></div> <a class="btn plain primary m-b-6" href="https://franceisai.com/contact">Contact me<i class="fa fa-long-arrow-right m-l-6"></i></a> <a class="btn outline primary" href="https://franceisai.com/about-us">or learn more about us<i class="fa fa-long-arrow-right m-l-6"></i></a></div></div></div><div class="footer-bottom p-y-10"><div class="container d-flex justify-content-center align-items-center flex-column"><div class="footer-menu m-b-6"><ul id="menu-menu-footer" class="nav-footer-menu m-t-lg d-flex flex-column flex-sm-row justify-content-center"><li id="menu-item-474" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-474"><a href="https://franceisai.com/about-us">About us</a></li><li id="menu-item-475" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-475"><a href="https://franceisai.com/startups#">Ressources</a></li><li id="menu-item-2370" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2370"><a href="https://franceisai.com/contact">Contact us</a></li></ul></div><div class="footer-information m-b-6"><div class="social-network-container d-flex"><div class="text-center social-network"> <a href="https://www.facebook.com/FranceisAI/" target="_blank"> <i class="fa fa-fw fa-lg fa-facebook"></i> </a></div><div class="text-center social-network"> <a href="https://twitter.com/franceisai" target="_blank"> <i class="fa fa-fw fa-lg fa-twitter"></i> </a></div><div class="text-center social-network"> <a href="https://www.linkedin.com/groups/8592074" target="_blank"> <i class="fa fa-fw fa-lg fa-linkedin"></i> </a></div></div></div><div class="footer-credits"><p> <a href="https://franceisai.com/">France is AI</a> - Copyright 2018 - Legal notice</p></div></div></div></footer><link rel="stylesheet" id="basecss-css" href="./France-is-AI_files/style(2).css" type="text/css" media="all"> <script type="text/javascript">/* <![CDATA[ */ var eucookielaw_data = {"euCookieSet":null,"autoBlock":"0","expireTimer":"180","scrollConsent":"0","networkShareURL":"","isCookiePage":"","isRefererWebsite":"","deleteCookieUrl":"https:\/\/franceisai.com\/startup\/goshaba-2?nocookie=1"}; /* ]]> */</script> <script type="text/javascript" src="./France-is-AI_files/scripts.js"></script> <div class="pea_cook_wrapper pea_cook_bottomright" style="color: rgb(255, 255, 255); background: rgba(0, 0, 0, 0.85); display: none;"><p>En continuant à utiliser le site, vous acceptez l’utilisation des cookies. <a style="color:#FFFFFF;" href="https://franceisai.com/startups#" id="fom">Plus d’informations</a> <button id="pea_cook_btn" class="pea_cook_btn" href="#">Accepter</button></p></div><div class="pea_cook_more_info_popover"><div class="pea_cook_more_info_popover_inner" style="color:#FFFFFF;background-color: rgba(0,0,0,0.9);"><p>Les paramètres des cookies sur ce site sont définis sur «&nbsp;accepter les cookies&nbsp;» pour vous offrir la meilleure expérience de navigation possible. Si vous continuez à utiliser ce site sans changer vos paramètres de cookies ou si vous cliquez sur "Accepter" ci-dessous, vous consentez à cela.</p><p><a style="color:#FFFFFF;" href="https://franceisai.com/startups#" id="pea_close">Fermer</a></p></div></div>
<span style="border-radius: 3px; text-indent: 20px; width: auto; padding: 0px 4px 0px 0px; text-align: center; font-style: normal; font-variant: normal; font-weight: bold; font-stretch: normal; font-size: 11px; line-height: 20px; font-family: &quot;Helvetica Neue&quot;, Helvetica, sans-serif; color: rgb(255, 255, 255); background: url(&quot;data:image/svg+xml;base64,...&quot;) 3px 50% / 14px 14px no-repeat rgb(189, 8, 28); position: absolute; opacity: 1; z-index: 8675309; display: none; cursor: pointer; border: none; -webkit-font-smoothing: antialiased; top: 10px; left: 563px;">Save</span><span style="width: 24px; height: 24px; background: url(&quot;data:image/svg+xml;base64,...&quot;) 50% 50% / 14px 14px no-repeat rgba(0, 0, 0, 0.4); position: absolute; opacity: 1; z-index: 8675309; display: none; cursor: pointer; border: none; border-radius: 12px; top: 8px; left: 1233px;"></span><iframe width="0" height="0" frameborder="0" src="./France-is-AI_files/saved_resource.html" id="GINGER_SOFTWARE_bubblesIFrame" scrolling="no" style="border: 0px solid; display: none; position: absolute; z-index: 2147483647; height: 0px; width: 0px; background-color: transparent;"></iframe><div id="GingerWidgetInfo" style="display:none;">{"version":"0.1.0.627","isExtension":true,"extensionName":"Chrome"}</div></body><script>(function(){(function(){
            //Todo:is injection needed here?
            var eventRegister = {};

            var findReactProp = function(elem){
                for(var key in elem){
                    if(key.indexOf("__reactInternalInstance")===0){
                        //var p = null;
                        //if(elem[key].memoizedProps){
                        //    p = elem[key].memoizedProps;
                        //} else if(elem[key]._currentElement){
                        //    p = elem[key]._currentElement.props
                        //}

                        //TODO: report if props is not found with Facebook version
                        return (elem[key].memoizedProps || elem[key]._currentElement.props);
                    }
                }
                return null;
            };

            document.addEventListener("gingerModule-eventEmitter-react-fire",function(e){
                //console.log("firing", e);
                var reactProps = findReactProp(document.activeElement);
                var eventName = e.detail.event;
                var eventParams = e.detail.params || {};
                eventParams.preventDefault = function(){};
                if(reactProps && eventName) {
                    reactProps[eventName](eventParams);
                }
            });
            document.addEventListener("gingerModule-eventEmitter-onselect",function(e){
                var reactProps = findReactProp(document.activeElement);
                //trigger("select");
                if(reactProps) {
                    reactProps.onSelect();
                }
            });
            document.addEventListener("gingerModule-eventEmitter-onpaste",function(e){
                var reactProps = findReactProp(document.activeElement);
                var pasteObj = {
                    defaultPrevented: false,
                    target: document.activeElement,
                    preventDefault: function() {},
                    clipboardData : {
                        getData: function () {
                            return e.detail || "";
                        },
                        items: ["text/plain"]
                    }
                };
                //trigger("paste",pasteObj);
                if(reactProps) {
                    reactProps.onPaste(pasteObj);
                }
            });

            var trigger = function(eventName,data){
                if(!eventRegister[eventName]) return;
                for(var i = 0; i<eventRegister[eventName].length; i++){
                    var listener = eventRegister[eventName][i];
                    listener(new CustomEvent(eventName),data);
                }
            };

            var nativeEventListener = document.addEventListener.bind(document);
            document.addEventListener = function(eventName, callback, options) {
                console.log("registering event",eventName);
                var eventRegisterItem = eventRegister[eventName] || [];
                eventRegisterItem.push(callback);
                eventRegister[eventName] = eventRegisterItem;
                nativeEventListener(eventName, callback, options);
            };

        })() })()</script></html>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_ai, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0031)https://franceisai.com/startups -->
# <html class="gr__franceisai_com" lang="fr-FR" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script async="" src="./France-is-AI_files/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="./France-is-AI_files/gtm.js">
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-M97KFNW');
#   </script>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_ai, 'html.parser')

print(soup.find_all('@'))
# Out:
# []

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_ai, 'html.parser')

print(soup.find_all('email'))
# Out:
# []

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_ai, 'html.parser')

print(soup.find_all('France'))
# Out:
# []

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_ai, 'html.parser')

print(soup.find_all('a'))
# Out:
# [<a href="https://franceisai.com/"><img alt="France is AI" class="img-responsive" src="./France-is-AI_files/france-is-ai-logo-startup.png" title="France is AI"/></a>, <a href="https://franceisai.com/startups#">Conferences</a>, <a href="https://franceisai.com/conferences/conference-2017">Conference 2017</a>, <a href="http://ai-night.com/">AI Night 2018</a>, <a href="https://franceisai.com/startups">Startups</a>, <a href="https://franceisai.com/research">Research</a>, <a href="https://franceisai.com/education">Education</a>, <a href="https://franceisai.com/community">Community</a>, <a href="https://franceisai.com/calendar">Calendar</a>, <a href="https://franceisai.com/about-us">About us</a>, <a href="https://franceisai.com/partners">Partners</a>, <a href="https://franceisai.com/startups#">EN</a>, <a href="https://franceisai.com/startups#">FR</a>, <a class="btn plain white primary" href="https://franceisai.com/startups/add-startup" target="">Add your start up<i class="fa fa-long-arrow-r
# ...
